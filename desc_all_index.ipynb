# %%
#RF12A

import numpy as np
import pandas as pd
from collections import namedtuple
from math import log10
from copy import copy, deepcopy
from sklearn.neighbors import KDTree
from collections import Counter
import os
import sys
np.set_printoptions(threshold=sys.maxsize)


Mol = namedtuple('Mol', ['symbols', 'coords', 'message'])

#symbols is a list of atomic name to be met in the pdb
#kdtrees - is a dictionary of the KD-trees for each element

PDB = namedtuple('PDB', ['symbols', 'kdtrees', 'coords'])


def read_xyz(filename):
    f = open(filename, 'r')
    data = f.readlines()
    f.close()
    message = data[1].rstrip("\n")
    symbols = []
    coords = np.array([]).reshape((0, 3)).astype(float)
    for item in data[2:]:
        if item[0] != "H":
            item = item.strip("\n")
            item = item.split(" ")
            item = list(filter(None, item))
            symbols.append(item[0])
            coords = np.concatenate((coords, np.array(item[1:]).reshape((1,3)).astype(float)), 0)
    mol = Mol(symbols = symbols, coords = coords, message = message)
    mol.coords.astype(float)
    return mol


def read_pdb(filename):
    f = open(filename, 'r')
    data = f.readlines()
    f.close()
    # retain only lines containing atomic coordinates
    data = [line.rstrip("\n") for line in data if line.startswith("ATOM") or line.startswith("HETATM")]
    symbols = ['C', 'O', 'N', 'S', 'P', 'M1', 'M2']
    coords = {'C': [], 'O': [], 'N': [], 'S': [], 'P': [], 'M1': [], 'M2': []}
    # read and keep coordinate per atom type
    for line in data:
        x = float(line[30:37])
        y = float(line[38:45])
        z = float(line[46:53])

        if len(line) < 80 or line[76:78] == "  ":
            if line.startswith("ATOM") or line[17:20] in ["CSO", "IAS", "PTR", "TPO", "SEP", "ACE", "PCA", "CSD", "LLP", "KCX"]:
                symbol = deepcopy(line[12:16]).strip()[0]
            elif line[17:20] == "MSE":
                symbol = deepcopy(line[12:16]).strip()
                if symbol != "SE":
                    symbol = symbol[0]
            else:
                symbol = deepcopy(line[12:16]).strip()

        elif line[76] == " ":
            symbol = line[77]

        else:
            symbol = line[76:78]

        if symbol in ['C', 'C1+', 'O', 'O1-', 'N', 'N1+', 'S', 'P', 'Cl']:
            
            if len(symbol) != 1:
                symbol = symbol[0]
            coords[symbol].append([x, y, z])
        elif symbol in ['LI', 'NA', 'K', 'RB', 'CS']:
            coords['M1'].append([x, y, z])
        elif symbol in ['AU', 'BA', 'CA', 'CD', 'SR', 'BE', 'CO', 'MG', 'CU', 'FE', 'HG', 'MN', 'NI', 'ZN' , 'Zn2+' , 'Zn']:
            coords['M2'].append([x, y, z])
        elif symbol == 'SE':
            coords['S'].append([x, y, z])
        elif symbol == 'H':
            continue
        else:
            print(symbol, line[0:78])
            raise ValueError("Unknown atomic symbol in pdb")

    kdtrees = {}

    # create a dict of KD trees
    for atom_type in symbols:
        coords[atom_type] = np.array(coords[atom_type])
        if len(coords[atom_type]) != 0:
            kdtrees[atom_type] = KDTree(coords[atom_type], leaf_size=10)

    pdb = PDB(symbols=symbols, kdtrees=kdtrees, coords=coords)

    return pdb

 
     

def RF_desc(mol, pdb):

    desc = [0.] * 63
    for atom_type in pdb.coords.keys():
        # check if the atom is in the structure
        # if not add zeros for the vector
        if len(pdb.coords[atom_type]) != 0:
            ind = pdb.kdtrees[atom_type].query_radius(mol.coords, r = 12)

            atom_type_list = []
            for i in range(mol.coords.shape[0]):
                
                atom_env_coords = pdb.coords[atom_type][ind[i], :]
                atom_lig_coords = mol.coords[i]
                
                #print(atom_type, mol.symbols[i], len(ind[i]))
                
                if atom_type == "C":
                    if mol.symbols[i] == "C":
                        desc[0] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[1] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[2] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[3] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[4] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[5] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[6] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[7] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[8] += len(ind[i])
                elif atom_type == "O":
                    if mol.symbols[i] == "C":
                        desc[9] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[10] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[11] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[12] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[13] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[14] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[15] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[16] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[17] += len(ind[i])
                elif atom_type == "N":
                    if mol.symbols[i] == "C":
                        desc[18] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[19] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[20] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[21] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[22] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[23] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[24] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[25] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[26] += len(ind[i])
                elif atom_type == "S":
                    if mol.symbols[i] == "C":
                        desc[27] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[28] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[29] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[30] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[31] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[32] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[33] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[34] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[35] += len(ind[i])
                elif atom_type == "P":
                    if mol.symbols[i] == "C":
                        desc[36] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[37] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[38] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[39] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[40] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[41] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[42] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[43] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[44] += len(ind[i])
                elif atom_type == "M1":
                    if mol.symbols[i] == "C":
                        desc[45] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[46] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[47] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[48] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[49] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[50] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[51] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[52] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[53] += len(ind[i])
                elif atom_type == "M2":
                    if mol.symbols[i] == "C":
                        desc[54] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[55] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[56] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[57] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[58] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[59] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[60] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[61] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[62] += len(ind[i])
    return desc

def compute(pdb_id):
    desc_arr = []
    mol_names_arr = []
    for i in range(1, 100):
        try:
            mol_names_arr.append(pdb_id + "_lig_{}".format(i))
            #print(pdb_id, "molnamesarr", mol_names_arr[-1])
            mol = read_xyz("./all/" + pdb_id + "/" + pdb_id + "_lig_{}.xyz".format(i))
            pdb = read_pdb("./all/" + pdb_id + "/" + pdb_id + "_prot_1.pdb")

            desc = RF_desc(mol, pdb)
            desc_arr.append(desc)
            
        except Exception as e:
            print("COMPUTE FINISHED", e)
            break
    return desc_arr, mol_names_arr


def main(): 
    data = pd.read_csv("./index_all.csv")
    codes = [code for code in list(Counter(data.docked_pdb).keys()) if len(code) == 4]
    X = []
    y = []
    try:
        for code in codes:
            desc_arr, mol_names_arr = compute(code)
            print("code, len", code, len(desc_arr), '\n')
            if desc_arr is not None:
                for desc_idx in range(len(desc_arr)):
                    desc_i = desc_arr[desc_idx]
                    mol_name_cur = mol_names_arr[desc_idx]
                    #print("DF SIZE:", mol_name_cur, len(data[data.pose_filename == mol_name_cur]))
                    X.append(desc_i)
                    y.append(-log10(data[data.pose_filename == mol_name_cur].koff_s.iloc[0]))
                    #print(desc_i, data[data.pose_filename == mol_name_cur].koff_s.iloc[0])
            else:
                X.append(desc_i)
                y.append(-log10(data[data.pose_filename == mol_name_cur].koff_s.iloc[0]))
                print(desc_i, data[data.pose_filename == mol_name_cur].koff_s.iloc[0])
    except Exception as e:
        print("error in ", code, mol_name_cur,e)

    X = np.array(X).astype(int)
    y = np.array(y)

    np.save("rf_X_all.npy", X)
    np.save("rf_y_all.npy", y)
        

if __name__ == "__main__":
    main()
# Out:
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1xal/1xal_lig_4.xyz'
# code, len 1xal 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2yme/2yme_lig_2.xyz'
# code, len 2yme 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3uzc/3uzc_lig_11.xyz'
# code, len 3uzc 10
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ug2/4ug2_lig_2.xyz'
# code, len 4ug2 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2ydv/2ydv_lig_6.xyz'
# code, len 2ydv 5
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3qak/3qak_lig_2.xyz'
# code, len 3qak 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3iar/3iar_lig_2.xyz'
# code, len 3iar 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5iz6/5iz6_lig_2.xyz'
# code, len 5iz6 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5z8h/5z8h_lig_2.xyz'
# code, len 5z8h 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1kvl/1kvl_lig_4.xyz'
# code, len 1kvl 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4wbg/4wbg_lig_2.xyz'
# code, len 4wbg 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2pu4/2pu4_lig_3.xyz'
# code, len 2pu4 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ksq/4ksq_lig_2.xyz'
# code, len 4ksq 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ksp/4ksp_lig_2.xyz'
# code, len 4ksp 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6gpx/6gpx_lig_3.xyz'
# code, len 6gpx 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek4/4ek4_lig_2.xyz'
# code, len 4ek4 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek6/4ek6_lig_2.xyz'
# code, len 4ek6 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkj/4fkj_lig_2.xyz'
# code, len 4fkj 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek8/4ek8_lig_6.xyz'
# code, len 4ek8 5
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3sw4/3sw4_lig_2.xyz'
# code, len 3sw4 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3sw7/3sw7_lig_2.xyz'
# code, len 3sw7 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek5/4ek5_lig_3.xyz'
# code, len 4ek5 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fko/4fko_lig_2.xyz'
# code, len 4fko 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkp/4fkp_lig_2.xyz'
# code, len 4fkp 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkq/4fkq_lig_2.xyz'
# code, len 4fkq 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkr/4fkr_lig_3.xyz'
# code, len 4fkr 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fks/4fks_lig_2.xyz'
# code, len 4fks 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkv/4fkv_lig_3.xyz'
# code, len 4fkv 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkt/4fkt_lig_2.xyz'
# code, len 4fkt 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fku/4fku_lig_2.xyz'
# code, len 4fku 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkw/4fkw_lig_2.xyz'
# code, len 4fkw 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkg/4fkg_lig_2.xyz'
# code, len 4fkg 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fki/4fki_lig_2.xyz'
# code, len 4fki 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f7n/4f7n_lig_3.xyz'
# code, len 4f7n 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f6u/4f6u_lig_2.xyz'
# code, len 4f6u 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f6w/4f6w_lig_2.xyz'
# code, len 4f6w 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f7l/4f7l_lig_2.xyz'
# code, len 4f7l 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5eqy/5eqy_lig_8.xyz'
# code, len 5eqy 7
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1nfx/1nfx_lig_5.xyz'
# code, len 1nfx 4
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4z9g/4z9g_lig_27.xyz'
# code, len 4z9g 26
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1u73/1u73_lig_3.xyz'
# code, len 1u73 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1u72/1u72_lig_3.xyz'
# code, len 1u72 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1u74/1u74_lig_2.xyz'
# code, len 1u74 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ekg/4ekg_lig_3.xyz'
# code, len 4ekg 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4eki/4eki_lig_2.xyz'
# code, len 4eki 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3qox/3qox_lig_2.xyz'
# code, len 3qox 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3g0b/3g0b_lig_3.xyz'
# code, len 3g0b 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2rgu/2rgu_lig_3.xyz'
# code, len 2rgu 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3bjm/3bjm_lig_2.xyz'
# code, len 3bjm 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1x70/1x70_lig_2.xyz'
# code, len 1x70 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3vjk/3vjk_lig_2.xyz'
# code, len 3vjk 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3w2t/3w2t_lig_2.xyz'
# code, len 3w2t 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1xkk/1xkk_lig_2.xyz'
# code, len 1xkk 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1qg6/1qg6_lig_2.xyz'
# code, len 1qg6 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4p5z/4p5z_lig_3.xyz'
# code, len 4p5z 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2aay/2aay_lig_3.xyz'
# code, len 2aay 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3nrc/3nrc_lig_6.xyz'
# code, len 3nrc 5
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4no7/4no7_lig_3.xyz'
# code, len 4no7 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3f9m/3f9m_lig_3.xyz'
# code, len 3f9m 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1jyq/1jyq_lig_3.xyz'
# code, len 1jyq 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ldo/3ldo_lig_2.xyz'
# code, len 3ldo 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ldp/3ldp_lig_8.xyz'
# code, len 3ldp 7
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5uen/5uen_lig_12.xyz'
# code, len 5uen 11
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6fag/6fag_lig_3.xyz'
# code, len 6fag 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6f3b/6f3b_lig_2.xyz'
# code, len 6f3b 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1czm/1czm_lig_4.xyz'
# code, len 1czm 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5gmm/5gmm_lig_2.xyz'
# code, len 5gmm 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4wr7/4wr7_lig_3.xyz'
# code, len 4wr7 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4qsi/4qsi_lig_4.xyz'
# code, len 4qsi 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3m98/3m98_lig_3.xyz'
# code, len 3m98 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4knj/4knj_lig_4.xyz'
# code, len 4knj 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3sbi/3sbi_lig_3.xyz'
# code, len 3sbi 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3s9t/3s9t_lig_2.xyz'
# code, len 3s9t 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5ll4/5ll4_lig_2.xyz'
# code, len 5ll4 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5fl5/5fl5_lig_8.xyz'
# code, len 5fl5 7
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6fe0/6fe0_lig_9.xyz'
# code, len 6fe0 8
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6h37/6h37_lig_14.xyz'
# code, len 6h37 13
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5ll5/5ll5_lig_3.xyz'
# code, len 5ll5 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5ll9/5ll9_lig_4.xyz'
# code, len 5ll9 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4kp5/4kp5_lig_3.xyz'
# code, len 4kp5 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6g7a/6g7a_lig_3.xyz'
# code, len 6g7a 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4qjo/4qjo_lig_5.xyz'
# code, len 4qjo 4
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4qjw/4qjw_lig_2.xyz'
# code, len 4qjw 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3p8o/3p8o_lig_2.xyz'
# code, len 3p8o 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3p8n/3p8n_lig_2.xyz'
# code, len 3p8n 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4dru/4dru_lig_9.xyz'
# code, len 4dru 8
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3rze/3rze_lig_2.xyz'
# code, len 3rze 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1qbs/1qbs_lig_3.xyz'
# code, len 1qbs 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ebw/1ebw_lig_13.xyz'
# code, len 1ebw 12
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ajv/1ajv_lig_5.xyz'
# code, len 1ajv 4
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4njv/4njv_lig_3.xyz'
# code, len 4njv 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ec2/1ec2_lig_7.xyz'
# code, len 1ec2 6
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ekv/3ekv_lig_2.xyz'
# code, len 3ekv 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1d4h/1d4h_lig_6.xyz'
# code, len 1d4h 5
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1eby/1eby_lig_2.xyz'
# code, len 1eby 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ebz/1ebz_lig_2.xyz'
# code, len 1ebz 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ec1/1ec1_lig_2.xyz'
# code, len 1ec1 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1d4i/1d4i_lig_2.xyz'
# code, len 1d4i 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ekx/3ekx_lig_2.xyz'
# code, len 3ekx 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1hxw/1hxw_lig_2.xyz'
# code, len 1hxw 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1hiv/1hiv_lig_2.xyz'
# code, len 1hiv 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ikw/1ikw_lig_2.xyz'
# code, len 1ikw 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2uwd/2uwd_lig_2.xyz'
# code, len 2uwd 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2bsm/2bsm_lig_5.xyz'
# code, len 2bsm 4
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j2x/5j2x_lig_2.xyz'
# code, len 5j2x 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6f1n/6f1n_lig_2.xyz'
# code, len 6f1n 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6elo/6elo_lig_3.xyz'
# code, len 6elo 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j64/5j64_lig_5.xyz'
# code, len 5j64 4
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6eln/6eln_lig_2.xyz'
# code, len 6eln 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j20/5j20_lig_3.xyz'
# code, len 5j20 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j86/5j86_lig_9.xyz'
# code, len 5j86 8
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j9x/5j9x_lig_5.xyz'
# code, len 5j9x 4
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6elp/6elp_lig_4.xyz'
# code, len 6elp 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j27/5j27_lig_2.xyz'
# code, len 5j27 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j82/5j82_lig_3.xyz'
# code, len 5j82 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lrz/5lrz_lig_2.xyz'
# code, len 5lrz 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lr7/5lr7_lig_2.xyz'
# code, len 5lr7 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2yki/2yki_lig_2.xyz'
# code, len 2yki 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lq9/5lq9_lig_2.xyz'
# code, len 5lq9 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5ls1/5ls1_lig_2.xyz'
# code, len 5ls1 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5t21/5t21_lig_2.xyz'
# code, len 5t21 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6eya/6eya_lig_2.xyz'
# code, len 6eya 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lo6/5lo6_lig_2.xyz'
# code, len 5lo6 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lnz/5lnz_lig_2.xyz'
# code, len 5lnz 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6ey8/6ey8_lig_2.xyz'
# code, len 6ey8 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4efu/4efu_lig_2.xyz'
# code, len 4efu 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6ey9/6ey9_lig_2.xyz'
# code, len 6ey9 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6eyb/6eyb_lig_2.xyz'
# code, len 6eyb 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5oci/5oci_lig_12.xyz'
# code, len 5oci 11
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5odx/5odx_lig_3.xyz'
# code, len 5odx 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5nyh/5nyh_lig_4.xyz'
# code, len 5nyh 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5od7/5od7_lig_8.xyz'
# code, len 5od7 7
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6ei5/6ei5_lig_2.xyz'
# code, len 6ei5 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lr1/5lr1_lig_3.xyz'
# code, len 5lr1 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6el5/6el5_lig_2.xyz'
# code, len 6el5 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lo5/5lo5_lig_2.xyz'
# code, len 5lo5 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2ykj/2ykj_lig_2.xyz'
# code, len 2ykj 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lny/5lny_lig_25.xyz'
# code, len 5lny 24
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4yay/4yay_lig_3.xyz'
# code, len 4yay 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6hlo/6hlo_lig_2.xyz'
# code, len 6hlo 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2nv6/2nv6_lig_2.xyz'
# code, len 2nv6 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2x22/2x22_lig_2.xyz'
# code, len 2x22 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2aqi/2aqi_lig_2.xyz'
# code, len 2aqi 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4iqk/4iqk_lig_2.xyz'
# code, len 4iqk 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5h0u/5h0u_lig_4.xyz'
# code, len 5h0u 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1hov/1hov_lig_4.xyz'
# code, len 1hov 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2ow1/2ow1_lig_4.xyz'
# code, len 2ow1 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5zhp/5zhp_lig_10.xyz'
# code, len 5zhp 9
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1kv1/1kv1_lig_3.xyz'
# code, len 1kv1 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1kv2/1kv2_lig_16.xyz'
# code, len 1kv2 15
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3zs5/3zs5_lig_2.xyz'
# code, len 3zs5 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3hll/3hll_lig_2.xyz'
# code, len 3hll 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5mtx/5mtx_lig_9.xyz'
# code, len 5mtx 8
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1oz1/1oz1_lig_2.xyz'
# code, len 1oz1 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5if1/5if1_lig_4.xyz'
# code, len 5if1 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1w98/1w98_lig_4.xyz'
# code, len 1w98 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ddu/3ddu_lig_4.xyz'
# code, len 3ddu 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1bil/1bil_lig_8.xyz'
# code, len 1bil 7
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2v0z/2v0z_lig_2.xyz'
# code, len 2v0z 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6c4d/6c4d_lig_34.xyz'
# code, len 6c4d 33
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ocz/4ocz_lig_2.xyz'
# code, len 4ocz 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4od0/4od0_lig_20.xyz'
# code, len 4od0 19
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5l8p/5l8p_lig_2.xyz'
# code, len 5l8p 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5l41/5l41_lig_2.xyz'
# code, len 5l41 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5l3u/5l3u_lig_2.xyz'
# code, len 5l3u 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2mgy/2mgy_lig_7.xyz'
# code, len 2mgy 6
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4wa4/4wa4_lig_2.xyz'
# code, len 4wa4 1

# %%
read_pdb('./all/1ajv/1ajv_prot_1.pdb')[1]
# Out:
# {'C': <sklearn.neighbors.kd_tree.KDTree at 0x25fa8320098>,
#  'O': <sklearn.neighbors.kd_tree.KDTree at 0x25fa8321d78>,
#  'N': <sklearn.neighbors.kd_tree.KDTree at 0x25fa8322248>,
#  'S': <sklearn.neighbors.kd_tree.KDTree at 0x25fa8320f08>}

# %%
#RFC12A

import numpy as np
import pandas as pd
from collections import namedtuple
from math import log10
from copy import copy, deepcopy
from sklearn.neighbors import KDTree
import os
import sys
np.set_printoptions(threshold=sys.maxsize)


Mol = namedtuple('Mol', ['symbols', 'coords', 'message'])

#symbols is a list of atomic name to be met in the pdb
#kdtrees - is a dictionary of the KD-trees for each element

PDB = namedtuple('PDB', ['symbols', 'kdtrees', 'coords'])


def read_xyz(filename):
    f = open(filename, 'r')
    data = f.readlines()
    f.close()
    message = data[1].rstrip("\n")
    symbols = []
    coords = np.array([]).reshape((0, 3)).astype(float)
    for item in data[2:]:
        if item[0] != "H":
            item = item.strip("\n")
            item = item.split(" ")
            item = list(filter(None, item))
            symbols.append(item[0])
            coords = np.concatenate((coords, np.array(item[1:]).reshape((1,3)).astype(float)), 0)
    mol = Mol(symbols = symbols, coords = coords, message = message)
    mol.coords.astype(float)
    return mol


def read_pdb(filename):
    f = open(filename, 'r')
    data = f.readlines()
    f.close()
    # retain only lines containing atomic coordinates
    data = [line.rstrip("\n") for line in data if line.startswith("ATOM") or line.startswith("HETATM")]
    symbols = ['C', 'O', 'N', 'S', 'P', 'M1', 'M2']
    coords = {'C': [], 'O': [], 'N': [], 'S': [], 'P': [], 'M1': [], 'M2': []}
    # read and keep coordinate per atom type
    for line in data:
        x = float(line[30:37])
        y = float(line[38:45])
        z = float(line[46:53])

        if len(line) < 80 or line[76:78] == "  ":
            if line.startswith("ATOM") or line[17:20] in ["CSO", "IAS", "PTR", "TPO", "SEP", "ACE", "PCA", "CSD", "LLP", "KCX"]:
                symbol = deepcopy(line[12:16]).strip()[0]
            elif line[17:20] == "MSE":
                symbol = deepcopy(line[12:16]).strip()
                if symbol != "SE":
                    symbol = symbol[0]
            else:
                symbol = deepcopy(line[12:16]).strip()

        elif line[76] == " ":
            symbol = line[77]

        else:
            symbol = line[76:78]

        if symbol in ['C', 'C1+', 'O', 'O1-', 'N', 'N1+', 'S', 'P', 'Cl']:
            
            if len(symbol) != 1:
                symbol = symbol[0]
            coords[symbol].append([x, y, z])
        elif symbol in ['LI', 'NA', 'K', 'RB', 'CS']:
            coords['M1'].append([x, y, z])
        elif symbol in ['AU', 'BA', 'CA', 'CD', 'SR', 'BE', 'CO', 'MG', 'CU', 'FE', 'HG', 'MN', 'NI', 'ZN' , 'Zn2+' , 'Zn']:
            coords['M2'].append([x, y, z])
        elif symbol == 'SE':
            coords['S'].append([x, y, z])
        elif symbol == 'H':
            continue
        else:
            print(symbol, line[0:78])
            raise ValueError("Unknown atomic symbol in pdb")

    kdtrees = {}

    # create a dict of KD trees
    for atom_type in symbols:
        coords[atom_type] = np.array(coords[atom_type])
        if len(coords[atom_type]) != 0:
            kdtrees[atom_type] = KDTree(coords[atom_type], leaf_size=10)

    pdb = PDB(symbols=symbols, kdtrees=kdtrees, coords=coords)

    return pdb

 
     

def RF_desc(mol, pdb):

    desc = [0.] * 7
    for atom_type in pdb.coords.keys():
        # check if the atom is in the structure
        # if not add zeros for the vector
        if len(pdb.coords[atom_type]) != 0:
            ind = pdb.kdtrees[atom_type].query_radius(mol.coords, r = 12)

            atom_type_list = []
            for i in range(mol.coords.shape[0]):
                
                atom_env_coords = pdb.coords[atom_type][ind[i], :]
                atom_lig_coords = mol.coords[i]
                
                #print(atom_type, mol.symbols[i], len(ind[i]))
                
                if atom_type == "C":
                    if mol.symbols[i] == "C":
                        desc[0] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[0] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[0] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[0] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[0] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[0] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[0] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[0] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[0] += len(ind[i])
                elif atom_type == "O":
                    if mol.symbols[i] == "C":
                        desc[1] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[1] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[1] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[1] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[1] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[1] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[1] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[1] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[1] += len(ind[i])
                elif atom_type == "N":
                    if mol.symbols[i] == "C":
                        desc[2] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[2] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[2] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[2] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[2] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[2] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[2] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[2] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[2] += len(ind[i])
                elif atom_type == "S":
                    if mol.symbols[i] == "C":
                        desc[3] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[3] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[3] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[3] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[3] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[3] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[3] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[3] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[3] += len(ind[i])
                elif atom_type == "P":
                    if mol.symbols[i] == "C":
                        desc[4] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[4] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[4] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[4] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[4] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[4] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[4] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[4] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[4] += len(ind[i])
                elif atom_type == "M1":
                    if mol.symbols[i] == "C":
                        desc[5] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[5] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[5] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[5] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[5] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[5] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[5] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[5] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[5] += len(ind[i])
                elif atom_type == "M2":
                    if mol.symbols[i] == "C":
                        desc[6] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[6] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[6] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[6] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[6] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[6] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[6] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[6] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[6] += len(ind[i])
    return desc

def compute(pdb_id):
    desc_arr = []
    mol_names_arr = []
    for i in range(1, 100):
        try:
            mol_names_arr.append(pdb_id + "_lig_{}".format(i))
            #print(pdb_id, "molnamesarr", mol_names_arr[-1])
            mol = read_xyz("./all/" + pdb_id + "/" + pdb_id + "_lig_{}.xyz".format(i))
            pdb = read_pdb("./all/" + pdb_id + "/" + pdb_id + "_prot_1.pdb")

            desc = RF_desc(mol, pdb)
            desc_arr.append(desc)
            
        except Exception as e:
            print("COMPUTE FINISHED", e)
            break
    return desc_arr, mol_names_arr


def main(): 
    data = pd.read_csv("./index_all.csv")
    codes = [code for code in list(Counter(data.docked_pdb).keys()) if len(code) == 4]
    X = []
    y = []
    try:
        for code in codes:
            desc_arr, mol_names_arr = compute(code)
            print("code, len", code, len(desc_arr), '\n')
            if desc_arr is not None:
                for desc_idx in range(len(desc_arr)):
                    desc_i = desc_arr[desc_idx]
                    mol_name_cur = mol_names_arr[desc_idx]
                    #print("DF SIZE:", mol_name_cur, len(data[data.pose_filename == mol_name_cur]))
                    X.append(desc_i)
                    y.append(-log10(data[data.pose_filename == mol_name_cur].koff_s.iloc[0]))
                    #print(desc_i, data[data.pose_filename == mol_name_cur].koff_s.iloc[0])
            else:
                X.append(desc_i)
                y.append(-log10(data[data.pose_filename == mol_name_cur].koff_s.iloc[0]))
                print(desc_i, data[data.pose_filename == mol_name_cur].koff_s.iloc[0])
    except Exception as e:
        print("error in ", code, mol_name_cur,e)

    X = np.array(X).astype(int)
    y = np.array(y)

    np.save("rfc_X_all.npy", X)
    np.save("rfc_y_all.npy", y)
        

if __name__ == "__main__":
    main()
# Out:
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1xal/1xal_lig_4.xyz'
# code, len 1xal 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2yme/2yme_lig_2.xyz'
# code, len 2yme 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3uzc/3uzc_lig_11.xyz'
# code, len 3uzc 10
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ug2/4ug2_lig_2.xyz'
# code, len 4ug2 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2ydv/2ydv_lig_6.xyz'
# code, len 2ydv 5
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3qak/3qak_lig_2.xyz'
# code, len 3qak 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3iar/3iar_lig_2.xyz'
# code, len 3iar 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5iz6/5iz6_lig_2.xyz'
# code, len 5iz6 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5z8h/5z8h_lig_2.xyz'
# code, len 5z8h 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1kvl/1kvl_lig_4.xyz'
# code, len 1kvl 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4wbg/4wbg_lig_2.xyz'
# code, len 4wbg 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2pu4/2pu4_lig_3.xyz'
# code, len 2pu4 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ksq/4ksq_lig_2.xyz'
# code, len 4ksq 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ksp/4ksp_lig_2.xyz'
# code, len 4ksp 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6gpx/6gpx_lig_3.xyz'
# code, len 6gpx 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek4/4ek4_lig_2.xyz'
# code, len 4ek4 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek6/4ek6_lig_2.xyz'
# code, len 4ek6 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkj/4fkj_lig_2.xyz'
# code, len 4fkj 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek8/4ek8_lig_6.xyz'
# code, len 4ek8 5
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3sw4/3sw4_lig_2.xyz'
# code, len 3sw4 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3sw7/3sw7_lig_2.xyz'
# code, len 3sw7 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek5/4ek5_lig_3.xyz'
# code, len 4ek5 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fko/4fko_lig_2.xyz'
# code, len 4fko 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkp/4fkp_lig_2.xyz'
# code, len 4fkp 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkq/4fkq_lig_2.xyz'
# code, len 4fkq 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkr/4fkr_lig_3.xyz'
# code, len 4fkr 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fks/4fks_lig_2.xyz'
# code, len 4fks 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkv/4fkv_lig_3.xyz'
# code, len 4fkv 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkt/4fkt_lig_2.xyz'
# code, len 4fkt 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fku/4fku_lig_2.xyz'
# code, len 4fku 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkw/4fkw_lig_2.xyz'
# code, len 4fkw 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkg/4fkg_lig_2.xyz'
# code, len 4fkg 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fki/4fki_lig_2.xyz'
# code, len 4fki 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f7n/4f7n_lig_3.xyz'
# code, len 4f7n 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f6u/4f6u_lig_2.xyz'
# code, len 4f6u 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f6w/4f6w_lig_2.xyz'
# code, len 4f6w 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f7l/4f7l_lig_2.xyz'
# code, len 4f7l 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5eqy/5eqy_lig_8.xyz'
# code, len 5eqy 7
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1nfx/1nfx_lig_5.xyz'
# code, len 1nfx 4
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4z9g/4z9g_lig_27.xyz'
# code, len 4z9g 26
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1u73/1u73_lig_3.xyz'
# code, len 1u73 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1u72/1u72_lig_3.xyz'
# code, len 1u72 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1u74/1u74_lig_2.xyz'
# code, len 1u74 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ekg/4ekg_lig_3.xyz'
# code, len 4ekg 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4eki/4eki_lig_2.xyz'
# code, len 4eki 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3qox/3qox_lig_2.xyz'
# code, len 3qox 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3g0b/3g0b_lig_3.xyz'
# code, len 3g0b 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2rgu/2rgu_lig_3.xyz'
# code, len 2rgu 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3bjm/3bjm_lig_2.xyz'
# code, len 3bjm 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1x70/1x70_lig_2.xyz'
# code, len 1x70 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3vjk/3vjk_lig_2.xyz'
# code, len 3vjk 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3w2t/3w2t_lig_2.xyz'
# code, len 3w2t 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1xkk/1xkk_lig_2.xyz'
# code, len 1xkk 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1qg6/1qg6_lig_2.xyz'
# code, len 1qg6 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4p5z/4p5z_lig_3.xyz'
# code, len 4p5z 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2aay/2aay_lig_3.xyz'
# code, len 2aay 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3nrc/3nrc_lig_6.xyz'
# code, len 3nrc 5
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4no7/4no7_lig_3.xyz'
# code, len 4no7 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3f9m/3f9m_lig_3.xyz'
# code, len 3f9m 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1jyq/1jyq_lig_3.xyz'
# code, len 1jyq 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ldo/3ldo_lig_2.xyz'
# code, len 3ldo 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ldp/3ldp_lig_8.xyz'
# code, len 3ldp 7
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5uen/5uen_lig_12.xyz'
# code, len 5uen 11
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6fag/6fag_lig_3.xyz'
# code, len 6fag 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6f3b/6f3b_lig_2.xyz'
# code, len 6f3b 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1czm/1czm_lig_4.xyz'
# code, len 1czm 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5gmm/5gmm_lig_2.xyz'
# code, len 5gmm 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4wr7/4wr7_lig_3.xyz'
# code, len 4wr7 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4qsi/4qsi_lig_4.xyz'
# code, len 4qsi 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3m98/3m98_lig_3.xyz'
# code, len 3m98 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4knj/4knj_lig_4.xyz'
# code, len 4knj 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3sbi/3sbi_lig_3.xyz'
# code, len 3sbi 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3s9t/3s9t_lig_2.xyz'
# code, len 3s9t 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5ll4/5ll4_lig_2.xyz'
# code, len 5ll4 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5fl5/5fl5_lig_8.xyz'
# code, len 5fl5 7
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6fe0/6fe0_lig_9.xyz'
# code, len 6fe0 8
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6h37/6h37_lig_14.xyz'
# code, len 6h37 13
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5ll5/5ll5_lig_3.xyz'
# code, len 5ll5 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5ll9/5ll9_lig_4.xyz'
# code, len 5ll9 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4kp5/4kp5_lig_3.xyz'
# code, len 4kp5 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6g7a/6g7a_lig_3.xyz'
# code, len 6g7a 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4qjo/4qjo_lig_5.xyz'
# code, len 4qjo 4
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4qjw/4qjw_lig_2.xyz'
# code, len 4qjw 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3p8o/3p8o_lig_2.xyz'
# code, len 3p8o 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3p8n/3p8n_lig_2.xyz'
# code, len 3p8n 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4dru/4dru_lig_9.xyz'
# code, len 4dru 8
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3rze/3rze_lig_2.xyz'
# code, len 3rze 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1qbs/1qbs_lig_3.xyz'
# code, len 1qbs 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ebw/1ebw_lig_13.xyz'
# code, len 1ebw 12
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ajv/1ajv_lig_5.xyz'
# code, len 1ajv 4
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4njv/4njv_lig_3.xyz'
# code, len 4njv 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ec2/1ec2_lig_7.xyz'
# code, len 1ec2 6
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ekv/3ekv_lig_2.xyz'
# code, len 3ekv 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1d4h/1d4h_lig_6.xyz'
# code, len 1d4h 5
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1eby/1eby_lig_2.xyz'
# code, len 1eby 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ebz/1ebz_lig_2.xyz'
# code, len 1ebz 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ec1/1ec1_lig_2.xyz'
# code, len 1ec1 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1d4i/1d4i_lig_2.xyz'
# code, len 1d4i 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ekx/3ekx_lig_2.xyz'
# code, len 3ekx 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1hxw/1hxw_lig_2.xyz'
# code, len 1hxw 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1hiv/1hiv_lig_2.xyz'
# code, len 1hiv 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ikw/1ikw_lig_2.xyz'
# code, len 1ikw 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2uwd/2uwd_lig_2.xyz'
# code, len 2uwd 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2bsm/2bsm_lig_5.xyz'
# code, len 2bsm 4
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j2x/5j2x_lig_2.xyz'
# code, len 5j2x 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6f1n/6f1n_lig_2.xyz'
# code, len 6f1n 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6elo/6elo_lig_3.xyz'
# code, len 6elo 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j64/5j64_lig_5.xyz'
# code, len 5j64 4
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6eln/6eln_lig_2.xyz'
# code, len 6eln 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j20/5j20_lig_3.xyz'
# code, len 5j20 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j86/5j86_lig_9.xyz'
# code, len 5j86 8
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j9x/5j9x_lig_5.xyz'
# code, len 5j9x 4
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6elp/6elp_lig_4.xyz'
# code, len 6elp 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j27/5j27_lig_2.xyz'
# code, len 5j27 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j82/5j82_lig_3.xyz'
# code, len 5j82 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lrz/5lrz_lig_2.xyz'
# code, len 5lrz 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lr7/5lr7_lig_2.xyz'
# code, len 5lr7 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2yki/2yki_lig_2.xyz'
# code, len 2yki 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lq9/5lq9_lig_2.xyz'
# code, len 5lq9 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5ls1/5ls1_lig_2.xyz'
# code, len 5ls1 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5t21/5t21_lig_2.xyz'
# code, len 5t21 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6eya/6eya_lig_2.xyz'
# code, len 6eya 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lo6/5lo6_lig_2.xyz'
# code, len 5lo6 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lnz/5lnz_lig_2.xyz'
# code, len 5lnz 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6ey8/6ey8_lig_2.xyz'
# code, len 6ey8 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4efu/4efu_lig_2.xyz'
# code, len 4efu 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6ey9/6ey9_lig_2.xyz'
# code, len 6ey9 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6eyb/6eyb_lig_2.xyz'
# code, len 6eyb 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5oci/5oci_lig_12.xyz'
# code, len 5oci 11
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5odx/5odx_lig_3.xyz'
# code, len 5odx 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5nyh/5nyh_lig_4.xyz'
# code, len 5nyh 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5od7/5od7_lig_8.xyz'
# code, len 5od7 7
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6ei5/6ei5_lig_2.xyz'
# code, len 6ei5 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lr1/5lr1_lig_3.xyz'
# code, len 5lr1 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6el5/6el5_lig_2.xyz'
# code, len 6el5 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lo5/5lo5_lig_2.xyz'
# code, len 5lo5 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2ykj/2ykj_lig_2.xyz'
# code, len 2ykj 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lny/5lny_lig_25.xyz'
# code, len 5lny 24
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4yay/4yay_lig_3.xyz'
# code, len 4yay 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6hlo/6hlo_lig_2.xyz'
# code, len 6hlo 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2nv6/2nv6_lig_2.xyz'
# code, len 2nv6 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2x22/2x22_lig_2.xyz'
# code, len 2x22 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2aqi/2aqi_lig_2.xyz'
# code, len 2aqi 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4iqk/4iqk_lig_2.xyz'
# code, len 4iqk 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5h0u/5h0u_lig_4.xyz'
# code, len 5h0u 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1hov/1hov_lig_4.xyz'
# code, len 1hov 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2ow1/2ow1_lig_4.xyz'
# code, len 2ow1 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5zhp/5zhp_lig_10.xyz'
# code, len 5zhp 9
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1kv1/1kv1_lig_3.xyz'
# code, len 1kv1 2
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1kv2/1kv2_lig_16.xyz'
# code, len 1kv2 15
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3zs5/3zs5_lig_2.xyz'
# code, len 3zs5 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3hll/3hll_lig_2.xyz'
# code, len 3hll 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5mtx/5mtx_lig_9.xyz'
# code, len 5mtx 8
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1oz1/1oz1_lig_2.xyz'
# code, len 1oz1 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5if1/5if1_lig_4.xyz'
# code, len 5if1 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1w98/1w98_lig_4.xyz'
# code, len 1w98 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ddu/3ddu_lig_4.xyz'
# code, len 3ddu 3
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1bil/1bil_lig_8.xyz'
# code, len 1bil 7
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2v0z/2v0z_lig_2.xyz'
# code, len 2v0z 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6c4d/6c4d_lig_34.xyz'
# code, len 6c4d 33
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ocz/4ocz_lig_2.xyz'
# code, len 4ocz 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4od0/4od0_lig_20.xyz'
# code, len 4od0 19
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5l8p/5l8p_lig_2.xyz'
# code, len 5l8p 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5l41/5l41_lig_2.xyz'
# code, len 5l41 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5l3u/5l3u_lig_2.xyz'
# code, len 5l3u 1
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2mgy/2mgy_lig_7.xyz'
# code, len 2mgy 6
#
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4wa4/4wa4_lig_2.xyz'
# code, len 4wa4 1

# %%
#SS12A

import numpy as np
import pandas as pd
from collections import namedtuple
from math import log10
from copy import copy, deepcopy
from sklearn.neighbors import KDTree
from collections import Counter
import os
import sys
np.set_printoptions(threshold=sys.maxsize)
from Bio import SeqUtils


Mol = namedtuple('Mol', ['symbols', 'coords', 'message'])

#symbols is a list of atomic name to be met in the pdb
#kdtrees - is a dictionary of the KD-trees for each atom

PDB = namedtuple('PDB', ['symbols', 'kdtrees', 'coords'])

#res_types is a dictionary of residue information (name, chain, number) and its secondary structure info

Sec = namedtuple('Sec', ['res_types'])


def read_xyz(filename):
    f = open(filename, 'r')
    data = f.readlines()
    f.close()
    message = data[1].rstrip("\n")
    symbols = []
    coords = np.array([]).reshape((0, 3)).astype(float)
    for item in data[2:]:
        if item[0] != "H":
            item = item.strip("\n")
            item = item.split(" ")
            item = list(filter(None, item))
            symbols.append(item[0])
            coords = np.concatenate((coords, np.array(item[1:]).reshape((1,3)).astype(float)), 0)
    mol = Mol(symbols = symbols, coords = coords, message = message)
    mol.coords.astype(float)
    return mol


def read_pdb(filename):
    f = open(filename, 'r')
    data = f.readlines()
    f.close()
    #retain only lines containing atomic coordinates
    data = [line.rstrip("\n") for line in data if line.startswith("ATOM") or line.startswith("HETATM")]


    xyz = []
    symbols = []

    for lines in data:  
        if (lines[11:17].strip(' ')[0]) != ('H') and (lines[11:17].strip(' ')[0]) not in ('K'):
            if ((((lines[71:80])).strip(' ')[:2]).upper()) not in  ('LI', 'NA', 'RB', 'CS', 
                                                     'AU', 'BA', 'CA', 'CD', 'SR', 
                                                     'BE', 'CO', 'MG', 'CU', 'FE', 
                                                     'HG', 'MN', 'NI', 'ZN'):
                    symbols.append((lines[16:20].strip(' '), lines[21:22], lines[23:26].strip(' ')))
                    x = float(lines[30:37])
                    y = float(lines[38:45])
                    z = float(lines[46:53])
                    xyz.append([x, y, z])

    res_coord_pair = []

    for i in range(len(symbols)):
        res_coord_pair.append((symbols[i], xyz[i]))


    unique_resnames = (list(Counter(symbols).keys()))

    coords = {}

    for res in res_coord_pair:
        res_cur = res[0]
        coord_cur = res[1]
        if res_cur not in coords.keys():
            coords[res_cur] = []
        coords[res_cur].append(coord_cur)

    kdtrees = {}

    #create a dict of KD trees
    for res in coords.keys():
        #coords[res] = np.array(coords[res])
        kdtrees[res] = KDTree(coords[res], leaf_size=10)

    pdb = PDB(symbols=unique_resnames, kdtrees=kdtrees, coords=coords)
    return pdb

 
def read_dssp(filename):
    f = open(filename, 'r')
    readl = f.readlines()
    f.close()
    dssps = [line.rstrip("\n") for line in readl[28:]]    

    ssr = []
    for lines in dssps:
            ssr.append((lines[13:14], lines[11:13].strip(' '), lines[7:11].strip(' '), lines[16:17]))

    ss=[]
    for lines in ssr:
        if lines != ('!', '', '', ' '):
            
            ss.append(lines)

    residues=[]
    
    resnames=[]
    reschains=[]
    resnums=[]

    for n in range(len(ss)):
        resnames.append((str(SeqUtils.IUPACData.protein_letters_1to3.get(ss[n][0]))).upper())
        reschains.append(ss[n][1])
        resnums.append(ss[n][2])
        residues.append((resnames[n], reschains[n], resnums[n]))
    
    restypes=[]
    
    for n in range(len(ss)):
        for i in (ss[n][3]):
            if i == (' '):
                i = 'R'
            restypes.append(i)
            
    # restypes is a dict of residues vs types
    res_types = {}

    res_types = dict(zip(residues, restypes))

    sec = Sec(res_types = res_types)
    return sec     


def SS_desc(mol, pdb, sec):
    desc = [0.] * 81
    for atom_type in pdb.coords.keys():
        # check if the residue is in the structure
        # if not add zeros for the vector
            ind = pdb.kdtrees[atom_type].query_radius(mol.coords, r = 12)
            counts = ind
            for i in range(len(ind)):
                if len(counts[i]) != 0:
                    counts[i] = np.array(1)
                else:
                    counts[i] = np.array(0)
            #for i in range(mol.coords.shape[0]):

                #print(atom_type, mol.symbols[i], len(ind[i]))

                if sec.res_types.get(atom_type) == "H":
                    if mol.symbols[i] == "C":
                        desc[0] = desc[0] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[1] = desc[1] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[2] = desc[2] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[3] = desc[3] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[4] = desc[4] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[5] = desc[5] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[6] = desc[6] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[7] = desc[7] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[8] = desc[8] + counts[i]

                if sec.res_types.get(atom_type) == "B":
                    if mol.symbols[i] == "C":
                        desc[9] = desc[9] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[10] = desc[10] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[11] = desc[11] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[12] = desc[12] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[13] = desc[13] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[14] = desc[14] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[15] = desc[15] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[16] = desc[16] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[17] = desc[17] + counts[i]

                if sec.res_types.get(atom_type) == "E":
                    if mol.symbols[i] == "C":
                        desc[18] = desc[18] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[19] = desc[19] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[20] = desc[20] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[21] = desc[21] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[22] = desc[22] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[23] = desc[23] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[24] = desc[24] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[25] = desc[25] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[26] = desc[26] + counts[i]

                if sec.res_types.get(atom_type) == "G":
                    if mol.symbols[i] == "C":
                        desc[27] = desc[27] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[28] = desc[28] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[29] = desc[29] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[30] = desc[30] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[31] = desc[31] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[32] = desc[32] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[33] = desc[33] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[34] = desc[34] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[35] = desc[35] + counts[i]

                if sec.res_types.get(atom_type) == "I":
                    if mol.symbols[i] == "C":
                        desc[36] = desc[36] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[37] = desc[37] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[38] = desc[38] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[39] = desc[39] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[40] = desc[40] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[41] = desc[41] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[42] = desc[42] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[43] = desc[43] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[44] = desc[44] + counts[i]

                if sec.res_types.get(atom_type) == "T":
                    if mol.symbols[i] == "C":
                        desc[45] = desc[45] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[46] = desc[46] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[47] = desc[47] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[48] = desc[48] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[49] = desc[49] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[50] = desc[50] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[51] = desc[51] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[52] = desc[52] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[53] = desc[53] + counts[i]

                if sec.res_types.get(atom_type) == "T":
                    if mol.symbols[i] == "C":
                        desc[54] = desc[54] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[55] = desc[55] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[56] = desc[56] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[57] = desc[57] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[58] = desc[58] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[59] = desc[59] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[60] = desc[60] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[61] = desc[61] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[62] = desc[62] + counts[i]

                if sec.res_types.get(atom_type) == "S":
                    if mol.symbols[i] == "C":
                        desc[63] = desc[63] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[64] = desc[64] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[65] = desc[65] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[66] = desc[66] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[67] = desc[67] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[68] = desc[68] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[69] = desc[69] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[70] = desc[70] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[71] = desc[71] + counts[i]

                if sec.res_types.get(atom_type) == "R":
                    if mol.symbols[i] == "C":
                        desc[72] = desc[72] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[73] = desc[73] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[74] = desc[74] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[75] = desc[75] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[76] = desc[76] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[77] = desc[77] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[78] = desc[78] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[79] = desc[79] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[80] = desc[80] + counts[i]
    return desc

def compute(pdb_id):
    desc_arr = []
    mol_names_arr = []
    for i in range(1, 100):
        try:
            mol_names_arr.append(pdb_id + "_lig_{}".format(i))
            #print(pdb_id, "molnamesarr", mol_names_arr[-1])
            mol = read_xyz("./all/" + pdb_id + "/" + pdb_id + "_lig_{}.xyz".format(i))
            pdb = read_pdb("./all/" + pdb_id + "/" + pdb_id + "_prot_1.pdb")
            sec = read_dssp("./all/" + pdb_id + "/" + pdb_id + "_sec_1.dssp")

            desc = SS_desc(mol, pdb, sec)
            desc_arr.append(desc)

        except Exception as e:
            print("COMPUTE FINISHED", e)
            break
    return desc_arr, mol_names_arr


def main(): 
    data = pd.read_csv("./index_all.csv")
    codes = [code for code in list(Counter(data.docked_pdb).keys()) if len(code) == 4]
    X = []
    y = []
    try:
        for code in codes:
            desc_arr, mol_names_arr = compute(code)
            print("code, len", code, len(desc_arr), '\n')
            if desc_arr is not None:
                for desc_idx in range(len(desc_arr)):
                    desc_i = desc_arr[desc_idx]
                    mol_name_cur = mol_names_arr[desc_idx]
                    print("DF SIZE:", mol_name_cur, len(data[data.pose_filename == mol_name_cur]))
                    X.append(desc_i)
                    y.append(-log10(data[data.pose_filename == mol_name_cur].koff_s.iloc[0]))
                    #print(desc_i, data[data.pose_filename == mol_name_cur].koff_s.iloc[0])
            else:
                X.append(desc_i)
                y.append(-log10(data[data.pose_filename == mol_name_cur].koff_s.iloc[0]))
    except Exception as e:
        print("error in ", code, mol_name_cur,e)

    X = np.array(X).astype(int)
    y = np.array(y).astype(float)

    np.save("ss_X_all.npy", X)
    np.save("ss_y_allnpy", y)
        

if __name__ == "__main__":
    main()
# Out:
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1xal/1xal_lig_4.xyz'
# code, len 1xal 3
#
# DF SIZE: 1xal_lig_1 1
# DF SIZE: 1xal_lig_2 1
# DF SIZE: 1xal_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2yme/2yme_lig_2.xyz'
# code, len 2yme 1
#
# DF SIZE: 2yme_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3uzc/3uzc_lig_11.xyz'
# code, len 3uzc 10
#
# DF SIZE: 3uzc_lig_1 1
# DF SIZE: 3uzc_lig_2 1
# DF SIZE: 3uzc_lig_3 1
# DF SIZE: 3uzc_lig_4 1
# DF SIZE: 3uzc_lig_5 1
# DF SIZE: 3uzc_lig_6 1
# DF SIZE: 3uzc_lig_7 1
# DF SIZE: 3uzc_lig_8 1
# DF SIZE: 3uzc_lig_9 1
# DF SIZE: 3uzc_lig_10 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ug2/4ug2_lig_2.xyz'
# code, len 4ug2 1
#
# DF SIZE: 4ug2_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2ydv/2ydv_lig_6.xyz'
# code, len 2ydv 5
#
# DF SIZE: 2ydv_lig_1 1
# DF SIZE: 2ydv_lig_2 1
# DF SIZE: 2ydv_lig_3 1
# DF SIZE: 2ydv_lig_4 1
# DF SIZE: 2ydv_lig_5 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3qak/3qak_lig_2.xyz'
# code, len 3qak 1
#
# DF SIZE: 3qak_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3iar/3iar_lig_2.xyz'
# code, len 3iar 1
#
# DF SIZE: 3iar_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5iz6/5iz6_lig_2.xyz'
# code, len 5iz6 1
#
# DF SIZE: 5iz6_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5z8h/5z8h_lig_2.xyz'
# code, len 5z8h 1
#
# DF SIZE: 5z8h_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1kvl/1kvl_lig_4.xyz'
# code, len 1kvl 3
#
# DF SIZE: 1kvl_lig_1 1
# DF SIZE: 1kvl_lig_2 1
# DF SIZE: 1kvl_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4wbg/4wbg_lig_2.xyz'
# code, len 4wbg 1
#
# DF SIZE: 4wbg_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2pu4/2pu4_lig_3.xyz'
# code, len 2pu4 2
#
# DF SIZE: 2pu4_lig_1 1
# DF SIZE: 2pu4_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ksq/4ksq_lig_2.xyz'
# code, len 4ksq 1
#
# DF SIZE: 4ksq_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ksp/4ksp_lig_2.xyz'
# code, len 4ksp 1
#
# DF SIZE: 4ksp_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6gpx/6gpx_lig_3.xyz'
# code, len 6gpx 2
#
# DF SIZE: 6gpx_lig_1 1
# DF SIZE: 6gpx_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek4/4ek4_lig_2.xyz'
# code, len 4ek4 1
#
# DF SIZE: 4ek4_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek6/4ek6_lig_2.xyz'
# code, len 4ek6 1
#
# DF SIZE: 4ek6_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkj/4fkj_lig_2.xyz'
# code, len 4fkj 1
#
# DF SIZE: 4fkj_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek8/4ek8_lig_6.xyz'
# code, len 4ek8 5
#
# DF SIZE: 4ek8_lig_1 1
# DF SIZE: 4ek8_lig_2 1
# DF SIZE: 4ek8_lig_3 1
# DF SIZE: 4ek8_lig_4 1
# DF SIZE: 4ek8_lig_5 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3sw4/3sw4_lig_2.xyz'
# code, len 3sw4 1
#
# DF SIZE: 3sw4_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3sw7/3sw7_lig_2.xyz'
# code, len 3sw7 1
#
# DF SIZE: 3sw7_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek5/4ek5_lig_3.xyz'
# code, len 4ek5 2
#
# DF SIZE: 4ek5_lig_1 1
# DF SIZE: 4ek5_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fko/4fko_lig_2.xyz'
# code, len 4fko 1
#
# DF SIZE: 4fko_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkp/4fkp_lig_2.xyz'
# code, len 4fkp 1
#
# DF SIZE: 4fkp_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkq/4fkq_lig_2.xyz'
# code, len 4fkq 1
#
# DF SIZE: 4fkq_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkr/4fkr_lig_3.xyz'
# code, len 4fkr 2
#
# DF SIZE: 4fkr_lig_1 1
# DF SIZE: 4fkr_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fks/4fks_lig_2.xyz'
# code, len 4fks 1
#
# DF SIZE: 4fks_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkv/4fkv_lig_3.xyz'
# code, len 4fkv 2
#
# DF SIZE: 4fkv_lig_1 1
# DF SIZE: 4fkv_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkt/4fkt_lig_2.xyz'
# code, len 4fkt 1
#
# DF SIZE: 4fkt_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fku/4fku_lig_2.xyz'
# code, len 4fku 1
#
# DF SIZE: 4fku_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkw/4fkw_lig_2.xyz'
# code, len 4fkw 1
#
# DF SIZE: 4fkw_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkg/4fkg_lig_2.xyz'
# code, len 4fkg 1
#
# DF SIZE: 4fkg_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fki/4fki_lig_2.xyz'
# code, len 4fki 1
#
# DF SIZE: 4fki_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f7n/4f7n_lig_3.xyz'
# code, len 4f7n 2
#
# DF SIZE: 4f7n_lig_1 1
# DF SIZE: 4f7n_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f6u/4f6u_lig_2.xyz'
# code, len 4f6u 1
#
# DF SIZE: 4f6u_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f6w/4f6w_lig_2.xyz'
# code, len 4f6w 1
#
# DF SIZE: 4f6w_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f7l/4f7l_lig_2.xyz'
# code, len 4f7l 1
#
# DF SIZE: 4f7l_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5eqy/5eqy_lig_8.xyz'
# code, len 5eqy 7
#
# DF SIZE: 5eqy_lig_1 1
# DF SIZE: 5eqy_lig_2 1
# DF SIZE: 5eqy_lig_3 1
# DF SIZE: 5eqy_lig_4 1
# DF SIZE: 5eqy_lig_5 1
# DF SIZE: 5eqy_lig_6 1
# DF SIZE: 5eqy_lig_7 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1nfx/1nfx_lig_5.xyz'
# code, len 1nfx 4
#
# DF SIZE: 1nfx_lig_1 1
# DF SIZE: 1nfx_lig_2 1
# DF SIZE: 1nfx_lig_3 1
# DF SIZE: 1nfx_lig_4 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4z9g/4z9g_lig_27.xyz'
# code, len 4z9g 26
#
# DF SIZE: 4z9g_lig_1 1
# DF SIZE: 4z9g_lig_2 1
# DF SIZE: 4z9g_lig_3 1
# DF SIZE: 4z9g_lig_4 1
# DF SIZE: 4z9g_lig_5 1
# DF SIZE: 4z9g_lig_6 1
# DF SIZE: 4z9g_lig_7 1
# DF SIZE: 4z9g_lig_8 1
# DF SIZE: 4z9g_lig_9 1
# DF SIZE: 4z9g_lig_10 1
# DF SIZE: 4z9g_lig_11 1
# DF SIZE: 4z9g_lig_12 1
# DF SIZE: 4z9g_lig_13 1
# DF SIZE: 4z9g_lig_14 1
# DF SIZE: 4z9g_lig_15 1
# DF SIZE: 4z9g_lig_16 1
# DF SIZE: 4z9g_lig_17 1
# DF SIZE: 4z9g_lig_18 1
# DF SIZE: 4z9g_lig_19 1
# DF SIZE: 4z9g_lig_20 1
# DF SIZE: 4z9g_lig_21 1
# DF SIZE: 4z9g_lig_22 1
# DF SIZE: 4z9g_lig_23 1
# DF SIZE: 4z9g_lig_24 1
# DF SIZE: 4z9g_lig_25 1
# DF SIZE: 4z9g_lig_26 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1u73/1u73_lig_3.xyz'
# code, len 1u73 2
#
# DF SIZE: 1u73_lig_1 1
# DF SIZE: 1u73_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1u72/1u72_lig_3.xyz'
# code, len 1u72 2
#
# DF SIZE: 1u72_lig_1 1
# DF SIZE: 1u72_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1u74/1u74_lig_2.xyz'
# code, len 1u74 1
#
# DF SIZE: 1u74_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ekg/4ekg_lig_3.xyz'
# code, len 4ekg 2
#
# DF SIZE: 4ekg_lig_1 1
# DF SIZE: 4ekg_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4eki/4eki_lig_2.xyz'
# code, len 4eki 1
#
# DF SIZE: 4eki_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3qox/3qox_lig_2.xyz'
# code, len 3qox 1
#
# DF SIZE: 3qox_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3g0b/3g0b_lig_3.xyz'
# code, len 3g0b 2
#
# DF SIZE: 3g0b_lig_1 1
# DF SIZE: 3g0b_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2rgu/2rgu_lig_3.xyz'
# code, len 2rgu 2
#
# DF SIZE: 2rgu_lig_1 1
# DF SIZE: 2rgu_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3bjm/3bjm_lig_2.xyz'
# code, len 3bjm 1
#
# DF SIZE: 3bjm_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1x70/1x70_lig_2.xyz'
# code, len 1x70 1
#
# DF SIZE: 1x70_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3vjk/3vjk_lig_2.xyz'
# code, len 3vjk 1
#
# DF SIZE: 3vjk_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3w2t/3w2t_lig_2.xyz'
# code, len 3w2t 1
#
# DF SIZE: 3w2t_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1xkk/1xkk_lig_2.xyz'
# code, len 1xkk 1
#
# DF SIZE: 1xkk_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1qg6/1qg6_lig_2.xyz'
# code, len 1qg6 1
#
# DF SIZE: 1qg6_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4p5z/4p5z_lig_3.xyz'
# code, len 4p5z 2
#
# DF SIZE: 4p5z_lig_1 1
# DF SIZE: 4p5z_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2aay/2aay_lig_3.xyz'
# code, len 2aay 2
#
# DF SIZE: 2aay_lig_1 1
# DF SIZE: 2aay_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3nrc/3nrc_lig_6.xyz'
# code, len 3nrc 5
#
# DF SIZE: 3nrc_lig_1 1
# DF SIZE: 3nrc_lig_2 1
# DF SIZE: 3nrc_lig_3 1
# DF SIZE: 3nrc_lig_4 1
# DF SIZE: 3nrc_lig_5 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4no7/4no7_lig_3.xyz'
# code, len 4no7 2
#
# DF SIZE: 4no7_lig_1 1
# DF SIZE: 4no7_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3f9m/3f9m_lig_3.xyz'
# code, len 3f9m 2
#
# DF SIZE: 3f9m_lig_1 1
# DF SIZE: 3f9m_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1jyq/1jyq_lig_3.xyz'
# code, len 1jyq 2
#
# DF SIZE: 1jyq_lig_1 1
# DF SIZE: 1jyq_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ldo/3ldo_lig_2.xyz'
# code, len 3ldo 1
#
# DF SIZE: 3ldo_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ldp/3ldp_lig_8.xyz'
# code, len 3ldp 7
#
# DF SIZE: 3ldp_lig_1 1
# DF SIZE: 3ldp_lig_2 1
# DF SIZE: 3ldp_lig_3 1
# DF SIZE: 3ldp_lig_4 1
# DF SIZE: 3ldp_lig_5 1
# DF SIZE: 3ldp_lig_6 1
# DF SIZE: 3ldp_lig_7 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5uen/5uen_lig_12.xyz'
# code, len 5uen 11
#
# DF SIZE: 5uen_lig_1 1
# DF SIZE: 5uen_lig_2 1
# DF SIZE: 5uen_lig_3 1
# DF SIZE: 5uen_lig_4 1
# DF SIZE: 5uen_lig_5 1
# DF SIZE: 5uen_lig_6 1
# DF SIZE: 5uen_lig_7 1
# DF SIZE: 5uen_lig_8 1
# DF SIZE: 5uen_lig_9 1
# DF SIZE: 5uen_lig_10 1
# DF SIZE: 5uen_lig_11 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6fag/6fag_lig_3.xyz'
# code, len 6fag 2
#
# DF SIZE: 6fag_lig_1 1
# DF SIZE: 6fag_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6f3b/6f3b_lig_2.xyz'
# code, len 6f3b 1
#
# DF SIZE: 6f3b_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1czm/1czm_lig_4.xyz'
# code, len 1czm 3
#
# DF SIZE: 1czm_lig_1 1
# DF SIZE: 1czm_lig_2 1
# DF SIZE: 1czm_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5gmm/5gmm_lig_2.xyz'
# code, len 5gmm 1
#
# DF SIZE: 5gmm_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4wr7/4wr7_lig_3.xyz'
# code, len 4wr7 2
#
# DF SIZE: 4wr7_lig_1 1
# DF SIZE: 4wr7_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4qsi/4qsi_lig_4.xyz'
# code, len 4qsi 3
#
# DF SIZE: 4qsi_lig_1 1
# DF SIZE: 4qsi_lig_2 1
# DF SIZE: 4qsi_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3m98/3m98_lig_3.xyz'
# code, len 3m98 2
#
# DF SIZE: 3m98_lig_1 1
# DF SIZE: 3m98_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4knj/4knj_lig_4.xyz'
# code, len 4knj 3
#
# DF SIZE: 4knj_lig_1 1
# DF SIZE: 4knj_lig_2 1
# DF SIZE: 4knj_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3sbi/3sbi_lig_3.xyz'
# code, len 3sbi 2
#
# DF SIZE: 3sbi_lig_1 1
# DF SIZE: 3sbi_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3s9t/3s9t_lig_2.xyz'
# code, len 3s9t 1
#
# DF SIZE: 3s9t_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5ll4/5ll4_lig_2.xyz'
# code, len 5ll4 1
#
# DF SIZE: 5ll4_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5fl5/5fl5_lig_8.xyz'
# code, len 5fl5 7
#
# DF SIZE: 5fl5_lig_1 1
# DF SIZE: 5fl5_lig_2 1
# DF SIZE: 5fl5_lig_3 1
# DF SIZE: 5fl5_lig_4 1
# DF SIZE: 5fl5_lig_5 1
# DF SIZE: 5fl5_lig_6 1
# DF SIZE: 5fl5_lig_7 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6fe0/6fe0_lig_9.xyz'
# code, len 6fe0 8
#
# DF SIZE: 6fe0_lig_1 1
# DF SIZE: 6fe0_lig_2 1
# DF SIZE: 6fe0_lig_3 1
# DF SIZE: 6fe0_lig_4 1
# DF SIZE: 6fe0_lig_5 1
# DF SIZE: 6fe0_lig_6 1
# DF SIZE: 6fe0_lig_7 1
# DF SIZE: 6fe0_lig_8 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6h37/6h37_lig_14.xyz'
# code, len 6h37 13
#
# DF SIZE: 6h37_lig_1 1
# DF SIZE: 6h37_lig_2 1
# DF SIZE: 6h37_lig_3 1
# DF SIZE: 6h37_lig_4 1
# DF SIZE: 6h37_lig_5 1
# DF SIZE: 6h37_lig_6 1
# DF SIZE: 6h37_lig_7 1
# DF SIZE: 6h37_lig_8 1
# DF SIZE: 6h37_lig_9 1
# DF SIZE: 6h37_lig_10 1
# DF SIZE: 6h37_lig_11 1
# DF SIZE: 6h37_lig_12 1
# DF SIZE: 6h37_lig_13 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5ll5/5ll5_lig_3.xyz'
# code, len 5ll5 2
#
# DF SIZE: 5ll5_lig_1 1
# DF SIZE: 5ll5_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5ll9/5ll9_lig_4.xyz'
# code, len 5ll9 3
#
# DF SIZE: 5ll9_lig_1 1
# DF SIZE: 5ll9_lig_2 1
# DF SIZE: 5ll9_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4kp5/4kp5_lig_3.xyz'
# code, len 4kp5 2
#
# DF SIZE: 4kp5_lig_1 1
# DF SIZE: 4kp5_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6g7a/6g7a_lig_3.xyz'
# code, len 6g7a 2
#
# DF SIZE: 6g7a_lig_1 1
# DF SIZE: 6g7a_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4qjo/4qjo_lig_5.xyz'
# code, len 4qjo 4
#
# DF SIZE: 4qjo_lig_1 1
# DF SIZE: 4qjo_lig_2 1
# DF SIZE: 4qjo_lig_3 1
# DF SIZE: 4qjo_lig_4 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4qjw/4qjw_lig_2.xyz'
# code, len 4qjw 1
#
# DF SIZE: 4qjw_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3p8o/3p8o_lig_2.xyz'
# code, len 3p8o 1
#
# DF SIZE: 3p8o_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3p8n/3p8n_lig_2.xyz'
# code, len 3p8n 1
#
# DF SIZE: 3p8n_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4dru/4dru_lig_9.xyz'
# code, len 4dru 8
#
# DF SIZE: 4dru_lig_1 1
# DF SIZE: 4dru_lig_2 1
# DF SIZE: 4dru_lig_3 1
# DF SIZE: 4dru_lig_4 1
# DF SIZE: 4dru_lig_5 1
# DF SIZE: 4dru_lig_6 1
# DF SIZE: 4dru_lig_7 1
# DF SIZE: 4dru_lig_8 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3rze/3rze_lig_2.xyz'
# code, len 3rze 1
#
# DF SIZE: 3rze_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1qbs/1qbs_lig_3.xyz'
# code, len 1qbs 2
#
# DF SIZE: 1qbs_lig_1 1
# DF SIZE: 1qbs_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ebw/1ebw_lig_13.xyz'
# code, len 1ebw 12
#
# DF SIZE: 1ebw_lig_1 1
# DF SIZE: 1ebw_lig_2 1
# DF SIZE: 1ebw_lig_3 1
# DF SIZE: 1ebw_lig_4 1
# DF SIZE: 1ebw_lig_5 1
# DF SIZE: 1ebw_lig_6 1
# DF SIZE: 1ebw_lig_7 1
# DF SIZE: 1ebw_lig_8 1
# DF SIZE: 1ebw_lig_9 1
# DF SIZE: 1ebw_lig_10 1
# DF SIZE: 1ebw_lig_11 1
# DF SIZE: 1ebw_lig_12 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ajv/1ajv_lig_5.xyz'
# code, len 1ajv 4
#
# DF SIZE: 1ajv_lig_1 1
# DF SIZE: 1ajv_lig_2 1
# DF SIZE: 1ajv_lig_3 1
# DF SIZE: 1ajv_lig_4 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4njv/4njv_lig_3.xyz'
# code, len 4njv 2
#
# DF SIZE: 4njv_lig_1 1
# DF SIZE: 4njv_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ec2/1ec2_lig_7.xyz'
# code, len 1ec2 6
#
# DF SIZE: 1ec2_lig_1 1
# DF SIZE: 1ec2_lig_2 1
# DF SIZE: 1ec2_lig_3 1
# DF SIZE: 1ec2_lig_4 1
# DF SIZE: 1ec2_lig_5 1
# DF SIZE: 1ec2_lig_6 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ekv/3ekv_lig_2.xyz'
# code, len 3ekv 1
#
# DF SIZE: 3ekv_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1d4h/1d4h_lig_6.xyz'
# code, len 1d4h 5
#
# DF SIZE: 1d4h_lig_1 1
# DF SIZE: 1d4h_lig_2 1
# DF SIZE: 1d4h_lig_3 1
# DF SIZE: 1d4h_lig_4 1
# DF SIZE: 1d4h_lig_5 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1eby/1eby_lig_2.xyz'
# code, len 1eby 1
#
# DF SIZE: 1eby_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ebz/1ebz_lig_2.xyz'
# code, len 1ebz 1
#
# DF SIZE: 1ebz_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ec1/1ec1_lig_2.xyz'
# code, len 1ec1 1
#
# DF SIZE: 1ec1_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1d4i/1d4i_lig_2.xyz'
# code, len 1d4i 1
#
# DF SIZE: 1d4i_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ekx/3ekx_lig_2.xyz'
# code, len 3ekx 1
#
# DF SIZE: 3ekx_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1hxw/1hxw_lig_2.xyz'
# code, len 1hxw 1
#
# DF SIZE: 1hxw_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1hiv/1hiv_lig_2.xyz'
# code, len 1hiv 1
#
# DF SIZE: 1hiv_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ikw/1ikw_lig_2.xyz'
# code, len 1ikw 1
#
# DF SIZE: 1ikw_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2uwd/2uwd_lig_2.xyz'
# code, len 2uwd 1
#
# DF SIZE: 2uwd_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2bsm/2bsm_lig_5.xyz'
# code, len 2bsm 4
#
# DF SIZE: 2bsm_lig_1 1
# DF SIZE: 2bsm_lig_2 1
# DF SIZE: 2bsm_lig_3 1
# DF SIZE: 2bsm_lig_4 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j2x/5j2x_lig_2.xyz'
# code, len 5j2x 1
#
# DF SIZE: 5j2x_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6f1n/6f1n_lig_2.xyz'
# code, len 6f1n 1
#
# DF SIZE: 6f1n_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6elo/6elo_lig_3.xyz'
# code, len 6elo 2
#
# DF SIZE: 6elo_lig_1 1
# DF SIZE: 6elo_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j64/5j64_lig_5.xyz'
# code, len 5j64 4
#
# DF SIZE: 5j64_lig_1 1
# DF SIZE: 5j64_lig_2 1
# DF SIZE: 5j64_lig_3 1
# DF SIZE: 5j64_lig_4 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6eln/6eln_lig_2.xyz'
# code, len 6eln 1
#
# DF SIZE: 6eln_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j20/5j20_lig_3.xyz'
# code, len 5j20 2
#
# DF SIZE: 5j20_lig_1 1
# DF SIZE: 5j20_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j86/5j86_lig_9.xyz'
# code, len 5j86 8
#
# DF SIZE: 5j86_lig_1 1
# DF SIZE: 5j86_lig_2 1
# DF SIZE: 5j86_lig_3 1
# DF SIZE: 5j86_lig_4 1
# DF SIZE: 5j86_lig_5 1
# DF SIZE: 5j86_lig_6 1
# DF SIZE: 5j86_lig_7 1
# DF SIZE: 5j86_lig_8 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j9x/5j9x_lig_5.xyz'
# code, len 5j9x 4
#
# DF SIZE: 5j9x_lig_1 1
# DF SIZE: 5j9x_lig_2 1
# DF SIZE: 5j9x_lig_3 1
# DF SIZE: 5j9x_lig_4 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6elp/6elp_lig_4.xyz'
# code, len 6elp 3
#
# DF SIZE: 6elp_lig_1 1
# DF SIZE: 6elp_lig_2 1
# DF SIZE: 6elp_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j27/5j27_lig_2.xyz'
# code, len 5j27 1
#
# DF SIZE: 5j27_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j82/5j82_lig_3.xyz'
# code, len 5j82 2
#
# DF SIZE: 5j82_lig_1 1
# DF SIZE: 5j82_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lrz/5lrz_lig_2.xyz'
# code, len 5lrz 1
#
# DF SIZE: 5lrz_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lr7/5lr7_lig_2.xyz'
# code, len 5lr7 1
#
# DF SIZE: 5lr7_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2yki/2yki_lig_2.xyz'
# code, len 2yki 1
#
# DF SIZE: 2yki_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lq9/5lq9_lig_2.xyz'
# code, len 5lq9 1
#
# DF SIZE: 5lq9_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5ls1/5ls1_lig_2.xyz'
# code, len 5ls1 1
#
# DF SIZE: 5ls1_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5t21/5t21_lig_2.xyz'
# code, len 5t21 1
#
# DF SIZE: 5t21_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6eya/6eya_lig_2.xyz'
# code, len 6eya 1
#
# DF SIZE: 6eya_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lo6/5lo6_lig_2.xyz'
# code, len 5lo6 1
#
# DF SIZE: 5lo6_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lnz/5lnz_lig_2.xyz'
# code, len 5lnz 1
#
# DF SIZE: 5lnz_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6ey8/6ey8_lig_2.xyz'
# code, len 6ey8 1
#
# DF SIZE: 6ey8_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4efu/4efu_lig_2.xyz'
# code, len 4efu 1
#
# DF SIZE: 4efu_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6ey9/6ey9_lig_2.xyz'
# code, len 6ey9 1
#
# DF SIZE: 6ey9_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6eyb/6eyb_lig_2.xyz'
# code, len 6eyb 1
#
# DF SIZE: 6eyb_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5oci/5oci_lig_12.xyz'
# code, len 5oci 11
#
# DF SIZE: 5oci_lig_1 1
# DF SIZE: 5oci_lig_2 1
# DF SIZE: 5oci_lig_3 1
# DF SIZE: 5oci_lig_4 1
# DF SIZE: 5oci_lig_5 1
# DF SIZE: 5oci_lig_6 1
# DF SIZE: 5oci_lig_7 1
# DF SIZE: 5oci_lig_8 1
# DF SIZE: 5oci_lig_9 1
# DF SIZE: 5oci_lig_10 1
# DF SIZE: 5oci_lig_11 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5odx/5odx_lig_3.xyz'
# code, len 5odx 2
#
# DF SIZE: 5odx_lig_1 1
# DF SIZE: 5odx_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5nyh/5nyh_lig_4.xyz'
# code, len 5nyh 3
#
# DF SIZE: 5nyh_lig_1 1
# DF SIZE: 5nyh_lig_2 1
# DF SIZE: 5nyh_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5od7/5od7_lig_8.xyz'
# code, len 5od7 7
#
# DF SIZE: 5od7_lig_1 1
# DF SIZE: 5od7_lig_2 1
# DF SIZE: 5od7_lig_3 1
# DF SIZE: 5od7_lig_4 1
# DF SIZE: 5od7_lig_5 1
# DF SIZE: 5od7_lig_6 1
# DF SIZE: 5od7_lig_7 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6ei5/6ei5_lig_2.xyz'
# code, len 6ei5 1
#
# DF SIZE: 6ei5_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lr1/5lr1_lig_3.xyz'
# code, len 5lr1 2
#
# DF SIZE: 5lr1_lig_1 1
# DF SIZE: 5lr1_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6el5/6el5_lig_2.xyz'
# code, len 6el5 1
#
# DF SIZE: 6el5_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lo5/5lo5_lig_2.xyz'
# code, len 5lo5 1
#
# DF SIZE: 5lo5_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2ykj/2ykj_lig_2.xyz'
# code, len 2ykj 1
#
# DF SIZE: 2ykj_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lny/5lny_lig_25.xyz'
# code, len 5lny 24
#
# DF SIZE: 5lny_lig_1 1
# DF SIZE: 5lny_lig_2 1
# DF SIZE: 5lny_lig_3 1
# DF SIZE: 5lny_lig_4 1
# DF SIZE: 5lny_lig_5 1
# DF SIZE: 5lny_lig_6 1
# DF SIZE: 5lny_lig_7 1
# DF SIZE: 5lny_lig_8 1
# DF SIZE: 5lny_lig_9 1
# DF SIZE: 5lny_lig_10 1
# DF SIZE: 5lny_lig_11 1
# DF SIZE: 5lny_lig_12 1
# DF SIZE: 5lny_lig_13 1
# DF SIZE: 5lny_lig_14 1
# DF SIZE: 5lny_lig_15 1
# DF SIZE: 5lny_lig_16 1
# DF SIZE: 5lny_lig_17 1
# DF SIZE: 5lny_lig_18 1
# DF SIZE: 5lny_lig_19 1
# DF SIZE: 5lny_lig_20 1
# DF SIZE: 5lny_lig_21 1
# DF SIZE: 5lny_lig_22 1
# DF SIZE: 5lny_lig_23 1
# DF SIZE: 5lny_lig_24 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4yay/4yay_lig_3.xyz'
# code, len 4yay 2
#
# DF SIZE: 4yay_lig_1 1
# DF SIZE: 4yay_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6hlo/6hlo_lig_2.xyz'
# code, len 6hlo 1
#
# DF SIZE: 6hlo_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2nv6/2nv6_lig_2.xyz'
# code, len 2nv6 1
#
# DF SIZE: 2nv6_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2x22/2x22_lig_2.xyz'
# code, len 2x22 1
#
# DF SIZE: 2x22_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2aqi/2aqi_lig_2.xyz'
# code, len 2aqi 1
#
# DF SIZE: 2aqi_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4iqk/4iqk_lig_2.xyz'
# code, len 4iqk 1
#
# DF SIZE: 4iqk_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5h0u/5h0u_lig_4.xyz'
# code, len 5h0u 3
#
# DF SIZE: 5h0u_lig_1 1
# DF SIZE: 5h0u_lig_2 1
# DF SIZE: 5h0u_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1hov/1hov_lig_4.xyz'
# code, len 1hov 3
#
# DF SIZE: 1hov_lig_1 1
# DF SIZE: 1hov_lig_2 1
# DF SIZE: 1hov_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2ow1/2ow1_lig_4.xyz'
# code, len 2ow1 3
#
# DF SIZE: 2ow1_lig_1 1
# DF SIZE: 2ow1_lig_2 1
# DF SIZE: 2ow1_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5zhp/5zhp_lig_10.xyz'
# code, len 5zhp 9
#
# DF SIZE: 5zhp_lig_1 1
# DF SIZE: 5zhp_lig_2 1
# DF SIZE: 5zhp_lig_3 1
# DF SIZE: 5zhp_lig_4 1
# DF SIZE: 5zhp_lig_5 1
# DF SIZE: 5zhp_lig_6 1
# DF SIZE: 5zhp_lig_7 1
# DF SIZE: 5zhp_lig_8 1
# DF SIZE: 5zhp_lig_9 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1kv1/1kv1_lig_3.xyz'
# code, len 1kv1 2
#
# DF SIZE: 1kv1_lig_1 1
# DF SIZE: 1kv1_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1kv2/1kv2_lig_16.xyz'
# code, len 1kv2 15
#
# DF SIZE: 1kv2_lig_1 1
# DF SIZE: 1kv2_lig_2 1
# DF SIZE: 1kv2_lig_3 1
# DF SIZE: 1kv2_lig_4 1
# DF SIZE: 1kv2_lig_5 1
# DF SIZE: 1kv2_lig_6 1
# DF SIZE: 1kv2_lig_7 1
# DF SIZE: 1kv2_lig_8 1
# DF SIZE: 1kv2_lig_9 1
# DF SIZE: 1kv2_lig_10 1
# DF SIZE: 1kv2_lig_11 1
# DF SIZE: 1kv2_lig_12 1
# DF SIZE: 1kv2_lig_13 1
# DF SIZE: 1kv2_lig_14 1
# DF SIZE: 1kv2_lig_15 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3zs5/3zs5_lig_2.xyz'
# code, len 3zs5 1
#
# DF SIZE: 3zs5_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3hll/3hll_lig_2.xyz'
# code, len 3hll 1
#
# DF SIZE: 3hll_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5mtx/5mtx_lig_9.xyz'
# code, len 5mtx 8
#
# DF SIZE: 5mtx_lig_1 1
# DF SIZE: 5mtx_lig_2 1
# DF SIZE: 5mtx_lig_3 1
# DF SIZE: 5mtx_lig_4 1
# DF SIZE: 5mtx_lig_5 1
# DF SIZE: 5mtx_lig_6 1
# DF SIZE: 5mtx_lig_7 1
# DF SIZE: 5mtx_lig_8 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1oz1/1oz1_lig_2.xyz'
# code, len 1oz1 1
#
# DF SIZE: 1oz1_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5if1/5if1_lig_4.xyz'
# code, len 5if1 3
#
# DF SIZE: 5if1_lig_1 1
# DF SIZE: 5if1_lig_2 1
# DF SIZE: 5if1_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1w98/1w98_lig_4.xyz'
# code, len 1w98 3
#
# DF SIZE: 1w98_lig_1 1
# DF SIZE: 1w98_lig_2 1
# DF SIZE: 1w98_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ddu/3ddu_lig_4.xyz'
# code, len 3ddu 3
#
# DF SIZE: 3ddu_lig_1 1
# DF SIZE: 3ddu_lig_2 1
# DF SIZE: 3ddu_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1bil/1bil_lig_8.xyz'
# code, len 1bil 7
#
# DF SIZE: 1bil_lig_1 1
# DF SIZE: 1bil_lig_2 1
# DF SIZE: 1bil_lig_3 1
# DF SIZE: 1bil_lig_4 1
# DF SIZE: 1bil_lig_5 1
# DF SIZE: 1bil_lig_6 1
# DF SIZE: 1bil_lig_7 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2v0z/2v0z_lig_2.xyz'
# code, len 2v0z 1
#
# DF SIZE: 2v0z_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6c4d/6c4d_lig_34.xyz'
# code, len 6c4d 33
#
# DF SIZE: 6c4d_lig_1 1
# DF SIZE: 6c4d_lig_2 1
# DF SIZE: 6c4d_lig_3 1
# DF SIZE: 6c4d_lig_4 1
# DF SIZE: 6c4d_lig_5 1
# DF SIZE: 6c4d_lig_6 1
# DF SIZE: 6c4d_lig_7 1
# DF SIZE: 6c4d_lig_8 1
# DF SIZE: 6c4d_lig_9 1
# DF SIZE: 6c4d_lig_10 1
# DF SIZE: 6c4d_lig_11 1
# DF SIZE: 6c4d_lig_12 1
# DF SIZE: 6c4d_lig_13 1
# DF SIZE: 6c4d_lig_14 1
# DF SIZE: 6c4d_lig_15 1
# DF SIZE: 6c4d_lig_16 1
# DF SIZE: 6c4d_lig_17 1
# DF SIZE: 6c4d_lig_18 1
# DF SIZE: 6c4d_lig_19 1
# DF SIZE: 6c4d_lig_20 1
# DF SIZE: 6c4d_lig_21 1
# DF SIZE: 6c4d_lig_22 1
# DF SIZE: 6c4d_lig_23 1
# DF SIZE: 6c4d_lig_24 1
# DF SIZE: 6c4d_lig_25 1
# DF SIZE: 6c4d_lig_26 1
# DF SIZE: 6c4d_lig_27 1
# DF SIZE: 6c4d_lig_28 1
# DF SIZE: 6c4d_lig_29 1
# DF SIZE: 6c4d_lig_30 1
# DF SIZE: 6c4d_lig_31 1
# DF SIZE: 6c4d_lig_32 1
# DF SIZE: 6c4d_lig_33 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ocz/4ocz_lig_2.xyz'
# code, len 4ocz 1
#
# DF SIZE: 4ocz_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4od0/4od0_lig_20.xyz'
# code, len 4od0 19
#
# DF SIZE: 4od0_lig_1 1
# DF SIZE: 4od0_lig_2 1
# DF SIZE: 4od0_lig_3 1
# DF SIZE: 4od0_lig_4 1
# DF SIZE: 4od0_lig_5 1
# DF SIZE: 4od0_lig_6 1
# DF SIZE: 4od0_lig_7 1
# DF SIZE: 4od0_lig_8 1
# DF SIZE: 4od0_lig_9 1
# DF SIZE: 4od0_lig_10 1
# DF SIZE: 4od0_lig_11 1
# DF SIZE: 4od0_lig_12 1
# DF SIZE: 4od0_lig_13 1
# DF SIZE: 4od0_lig_14 1
# DF SIZE: 4od0_lig_15 1
# DF SIZE: 4od0_lig_16 1
# DF SIZE: 4od0_lig_17 1
# DF SIZE: 4od0_lig_18 1
# DF SIZE: 4od0_lig_19 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5l8p/5l8p_lig_2.xyz'
# code, len 5l8p 1
#
# DF SIZE: 5l8p_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5l41/5l41_lig_2.xyz'
# code, len 5l41 1
#
# DF SIZE: 5l41_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5l3u/5l3u_lig_2.xyz'
# code, len 5l3u 1
#
# DF SIZE: 5l3u_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2mgy/2mgy_lig_7.xyz'
# code, len 2mgy 6
#
# DF SIZE: 2mgy_lig_1 1
# DF SIZE: 2mgy_lig_2 1
# DF SIZE: 2mgy_lig_3 1
# DF SIZE: 2mgy_lig_4 1
# DF SIZE: 2mgy_lig_5 1
# DF SIZE: 2mgy_lig_6 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4wa4/4wa4_lig_2.xyz'
# code, len 4wa4 1
#
# DF SIZE: 4wa4_lig_1 1

# %%
#SSC12A

import numpy as np
import pandas as pd
from collections import namedtuple
from math import log10
from copy import copy, deepcopy
from sklearn.neighbors import KDTree
from collections import Counter
import os
import sys
np.set_printoptions(threshold=sys.maxsize)
from Bio import SeqUtils


Mol = namedtuple('Mol', ['symbols', 'coords', 'message'])

#symbols is a list of atomic name to be met in the pdb
#kdtrees - is a dictionary of the KD-trees for each atom

PDB = namedtuple('PDB', ['symbols', 'kdtrees', 'coords'])

#res_types is a dictionary of residue information (name, chain, number) and its secondary structure info

Sec = namedtuple('Sec', ['res_types'])


def read_xyz(filename):
    f = open(filename, 'r')
    data = f.readlines()
    f.close()
    message = data[1].rstrip("\n")
    symbols = []
    coords = np.array([]).reshape((0, 3)).astype(float)
    for item in data[2:]:
        if item[0] != "H":
            item = item.strip("\n")
            item = item.split(" ")
            item = list(filter(None, item))
            symbols.append(item[0])
            coords = np.concatenate((coords, np.array(item[1:]).reshape((1,3)).astype(float)), 0)
    mol = Mol(symbols = symbols, coords = coords, message = message)
    mol.coords.astype(float)
    return mol


def read_pdb(filename):
    f = open(filename, 'r')
    data = f.readlines()
    f.close()
    #retain only lines containing atomic coordinates
    data = [line.rstrip("\n") for line in data if line.startswith("ATOM") or line.startswith("HETATM")]


    xyz = []
    symbols = []

    for lines in data:  
        if (lines[11:17].strip(' ')[0]) != ('H') and (lines[11:17].strip(' ')[0]) not in ('K'):
            if ((((lines[71:80])).strip(' ')[:2]).upper()) not in  ('LI', 'NA', 'RB', 'CS', 
                                                     'AU', 'BA', 'CA', 'CD', 'SR', 
                                                     'BE', 'CO', 'MG', 'CU', 'FE', 
                                                     'HG', 'MN', 'NI', 'ZN'):
                    symbols.append((lines[16:20].strip(' '), lines[21:22], lines[23:26].strip(' ')))
                    x = float(lines[30:37])
                    y = float(lines[38:45])
                    z = float(lines[46:53])
                    xyz.append([x, y, z])

    res_coord_pair = []

    for i in range(len(symbols)):
        res_coord_pair.append((symbols[i], xyz[i]))


    unique_resnames = (list(Counter(symbols).keys()))

    coords = {}

    for res in res_coord_pair:
        res_cur = res[0]
        coord_cur = res[1]
        if res_cur not in coords.keys():
            coords[res_cur] = []
        coords[res_cur].append(coord_cur)

    kdtrees = {}

    #create a dict of KD trees
    for res in coords.keys():
        #coords[res] = np.array(coords[res])
        kdtrees[res] = KDTree(coords[res], leaf_size=10)

    pdb = PDB(symbols=unique_resnames, kdtrees=kdtrees, coords=coords)
    return pdb

 
def read_dssp(filename):
    f = open(filename, 'r')
    readl = f.readlines()
    f.close()
    dssps = [line.rstrip("\n") for line in readl[28:]]    

    ssr = []
    for lines in dssps:
            ssr.append((lines[13:14], lines[11:13].strip(' '), lines[7:11].strip(' '), lines[16:17]))

    ss=[]
    for lines in ssr:
        if lines != ('!', '', '', ' '):
            
            ss.append(lines)

    residues=[]
    
    resnames=[]
    reschains=[]
    resnums=[]

    for n in range(len(ss)):
        resnames.append((str(SeqUtils.IUPACData.protein_letters_1to3.get(ss[n][0]))).upper())
        reschains.append(ss[n][1])
        resnums.append(ss[n][2])
        residues.append((resnames[n], reschains[n], resnums[n]))
    
    restypes=[]
    
    for n in range(len(ss)):
        for i in (ss[n][3]):
            if i == (' '):
                i = 'R'
            restypes.append(i)
            
    # restypes is a dict of residues vs types
    res_types = {}

    res_types = dict(zip(residues, restypes))

    sec = Sec(res_types = res_types)
    return sec     


def SS_desc(mol, pdb, sec):
    desc = [0.] * 9
    for atom_type in pdb.coords.keys():
        # check if the residue is in the structure
        # if not add zeros for the vector
            ind = pdb.kdtrees[atom_type].query_radius(mol.coords, r = 12)
            counts = ind
            for i in range(len(ind)):
                if len(counts[i]) != 0:
                    counts[i] = np.array(1)
                else:
                    counts[i] = np.array(0)
            #for i in range(mol.coords.shape[0]):

                #print(atom_type, mol.symbols[i], len(ind[i]))

                if sec.res_types.get(atom_type) == "H":
                    if mol.symbols[i] == "C":
                        desc[0] = desc[0] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[0] = desc[0] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[0] = desc[0] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[0] = desc[0] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[0] = desc[0] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[0] = desc[0] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[0] = desc[0] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[0] = desc[0] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[0] = desc[0] + counts[i]

                if sec.res_types.get(atom_type) == "B":
                    if mol.symbols[i] == "C":
                        desc[1] = desc[1] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[1] = desc[1] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[1] = desc[1] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[1] = desc[1] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[1] = desc[1] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[1] = desc[1] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[1] = desc[1] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[1] = desc[1] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[1] = desc[1] + counts[i]

                if sec.res_types.get(atom_type) == "E":
                    if mol.symbols[i] == "C":
                        desc[2] = desc[2] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[2] = desc[2] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[2] = desc[2] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[2] = desc[2] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[2] = desc[2] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[2] = desc[2] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[2] = desc[2] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[2] = desc[2] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[2] = desc[2] + counts[i]

                if sec.res_types.get(atom_type) == "G":
                    if mol.symbols[i] == "C":
                        desc[3] = desc[3] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[3] = desc[3] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[3] = desc[3] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[3] = desc[3] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[3] = desc[3] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[3] = desc[3] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[3] = desc[3] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[3] = desc[3] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[3] = desc[3] + counts[i]

                if sec.res_types.get(atom_type) == "I":
                    if mol.symbols[i] == "C":
                        desc[4] = desc[4] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[4] = desc[4] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[4] = desc[4] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[4] = desc[4] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[4] = desc[4] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[4] = desc[4] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[4] = desc[4] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[4] = desc[4] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[4] = desc[4] + counts[i]

                if sec.res_types.get(atom_type) == "T":
                    if mol.symbols[i] == "C":
                        desc[5] = desc[5] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[5] = desc[5] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[5] = desc[5] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[5] = desc[5] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[5] = desc[5] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[5] = desc[5] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[5] = desc[5] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[5] = desc[5] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[5] = desc[5] + counts[i]

                if sec.res_types.get(atom_type) == "T":
                    if mol.symbols[i] == "C":
                        desc[6] = desc[6] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[6] = desc[6] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[6] = desc[6] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[6] = desc[6] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[6] = desc[6] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[6] = desc[6] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[6] = desc[6] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[6] = desc[6] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[6] = desc[6] + counts[i]

                if sec.res_types.get(atom_type) == "S":
                    if mol.symbols[i] == "C":
                        desc[7] = desc[7] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[7] = desc[7] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[7] = desc[7] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[7] = desc[7] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[7] = desc[7] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[7] = desc[7] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[7] = desc[7] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[7] = desc[7] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[7] = desc[7] + counts[i]

                if sec.res_types.get(atom_type) == "R":
                    if mol.symbols[i] == "C":
                        desc[8] = desc[8] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[8] = desc[8] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[8] = desc[8] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[8] = desc[8] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[8] = desc[8] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[8] = desc[8] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[8] = desc[8] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[8] = desc[8] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[8] = desc[8] + counts[i]
    return desc

def compute(pdb_id):
    desc_arr = []
    mol_names_arr = []
    for i in range(1, 100):
        try:
            mol_names_arr.append(pdb_id + "_lig_{}".format(i))
            #print(pdb_id, "molnamesarr", mol_names_arr[-1])
            mol = read_xyz("./all/" + pdb_id + "/" + pdb_id + "_lig_{}.xyz".format(i))
            pdb = read_pdb("./all/" + pdb_id + "/" + pdb_id + "_prot_1.pdb")
            sec = read_dssp("./all/" + pdb_id + "/" + pdb_id + "_sec_1.dssp")

            desc = SS_desc(mol, pdb, sec)
            desc_arr.append(desc)

        except Exception as e:
            print("COMPUTE FINISHED", e)
            break
    return desc_arr, mol_names_arr


def main(): 
    data = pd.read_csv("./index_all.csv")
    codes = [code for code in list(Counter(data.docked_pdb).keys()) if len(code) == 4]
    X = []
    y = []
    z = []
    t = []
    try:
        for code in codes:
            desc_arr, mol_names_arr = compute(code)
            print("code, len", code, len(desc_arr), '\n')
            if desc_arr is not None:
                for desc_idx in range(len(desc_arr)):
                    desc_i = desc_arr[desc_idx]
                    mol_name_cur = mol_names_arr[desc_idx]
                    print("DF SIZE:", mol_name_cur, len(data[data.pose_filename == mol_name_cur]))
                    X.append(desc_i)
                    y.append(-log10(data[data.pose_filename == mol_name_cur].koff_s.iloc[0]))
                    z.append(data[data.pose_filename == mol_name_cur].smiles.iloc[0])
                    t.append(data[data.pose_filename == mol_name_cur].target.iloc[0])
                    #print(desc_i, data[data.pose_filename == mol_name_cur].koff_s.iloc[0])
            else:
                X.append(desc_i)
                y.append(-log10(data[data.pose_filename == mol_name_cur].koff_s.iloc[0]))
                z.append(data[data.pose_filename == mol_name_cur].smiles.iloc[0])
                t.append(data[data.pose_filename == mol_name_cur].target.iloc[0])

    except Exception as e:
        print("error in ", code, mol_name_cur,e)

    X = np.array(X).astype(int)
    y = np.array(y).astype(float)
    z = np.array(z)
    t = np.array(t)


    np.save("ssc_X_all.npy", X)
    np.save("ssc_y_all.npy", y)
    np.save("smi_all.npy", z)
    np.save("target_all.npy", t)

    
if __name__ == "__main__":
    main()
# Out:
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1xal/1xal_lig_4.xyz'
# code, len 1xal 3
#
# DF SIZE: 1xal_lig_1 1
# DF SIZE: 1xal_lig_2 1
# DF SIZE: 1xal_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2yme/2yme_lig_2.xyz'
# code, len 2yme 1
#
# DF SIZE: 2yme_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3uzc/3uzc_lig_11.xyz'
# code, len 3uzc 10
#
# DF SIZE: 3uzc_lig_1 1
# DF SIZE: 3uzc_lig_2 1
# DF SIZE: 3uzc_lig_3 1
# DF SIZE: 3uzc_lig_4 1
# DF SIZE: 3uzc_lig_5 1
# DF SIZE: 3uzc_lig_6 1
# DF SIZE: 3uzc_lig_7 1
# DF SIZE: 3uzc_lig_8 1
# DF SIZE: 3uzc_lig_9 1
# DF SIZE: 3uzc_lig_10 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ug2/4ug2_lig_2.xyz'
# code, len 4ug2 1
#
# DF SIZE: 4ug2_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2ydv/2ydv_lig_6.xyz'
# code, len 2ydv 5
#
# DF SIZE: 2ydv_lig_1 1
# DF SIZE: 2ydv_lig_2 1
# DF SIZE: 2ydv_lig_3 1
# DF SIZE: 2ydv_lig_4 1
# DF SIZE: 2ydv_lig_5 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3qak/3qak_lig_2.xyz'
# code, len 3qak 1
#
# DF SIZE: 3qak_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3iar/3iar_lig_2.xyz'
# code, len 3iar 1
#
# DF SIZE: 3iar_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5iz6/5iz6_lig_2.xyz'
# code, len 5iz6 1
#
# DF SIZE: 5iz6_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5z8h/5z8h_lig_2.xyz'
# code, len 5z8h 1
#
# DF SIZE: 5z8h_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1kvl/1kvl_lig_4.xyz'
# code, len 1kvl 3
#
# DF SIZE: 1kvl_lig_1 1
# DF SIZE: 1kvl_lig_2 1
# DF SIZE: 1kvl_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4wbg/4wbg_lig_2.xyz'
# code, len 4wbg 1
#
# DF SIZE: 4wbg_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2pu4/2pu4_lig_3.xyz'
# code, len 2pu4 2
#
# DF SIZE: 2pu4_lig_1 1
# DF SIZE: 2pu4_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ksq/4ksq_lig_2.xyz'
# code, len 4ksq 1
#
# DF SIZE: 4ksq_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ksp/4ksp_lig_2.xyz'
# code, len 4ksp 1
#
# DF SIZE: 4ksp_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6gpx/6gpx_lig_3.xyz'
# code, len 6gpx 2
#
# DF SIZE: 6gpx_lig_1 1
# DF SIZE: 6gpx_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek4/4ek4_lig_2.xyz'
# code, len 4ek4 1
#
# DF SIZE: 4ek4_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek6/4ek6_lig_2.xyz'
# code, len 4ek6 1
#
# DF SIZE: 4ek6_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkj/4fkj_lig_2.xyz'
# code, len 4fkj 1
#
# DF SIZE: 4fkj_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek8/4ek8_lig_6.xyz'
# code, len 4ek8 5
#
# DF SIZE: 4ek8_lig_1 1
# DF SIZE: 4ek8_lig_2 1
# DF SIZE: 4ek8_lig_3 1
# DF SIZE: 4ek8_lig_4 1
# DF SIZE: 4ek8_lig_5 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3sw4/3sw4_lig_2.xyz'
# code, len 3sw4 1
#
# DF SIZE: 3sw4_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3sw7/3sw7_lig_2.xyz'
# code, len 3sw7 1
#
# DF SIZE: 3sw7_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek5/4ek5_lig_3.xyz'
# code, len 4ek5 2
#
# DF SIZE: 4ek5_lig_1 1
# DF SIZE: 4ek5_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fko/4fko_lig_2.xyz'
# code, len 4fko 1
#
# DF SIZE: 4fko_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkp/4fkp_lig_2.xyz'
# code, len 4fkp 1
#
# DF SIZE: 4fkp_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkq/4fkq_lig_2.xyz'
# code, len 4fkq 1
#
# DF SIZE: 4fkq_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkr/4fkr_lig_3.xyz'
# code, len 4fkr 2
#
# DF SIZE: 4fkr_lig_1 1
# DF SIZE: 4fkr_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fks/4fks_lig_2.xyz'
# code, len 4fks 1
#
# DF SIZE: 4fks_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkv/4fkv_lig_3.xyz'
# code, len 4fkv 2
#
# DF SIZE: 4fkv_lig_1 1
# DF SIZE: 4fkv_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkt/4fkt_lig_2.xyz'
# code, len 4fkt 1
#
# DF SIZE: 4fkt_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fku/4fku_lig_2.xyz'
# code, len 4fku 1
#
# DF SIZE: 4fku_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkw/4fkw_lig_2.xyz'
# code, len 4fkw 1
#
# DF SIZE: 4fkw_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkg/4fkg_lig_2.xyz'
# code, len 4fkg 1
#
# DF SIZE: 4fkg_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fki/4fki_lig_2.xyz'
# code, len 4fki 1
#
# DF SIZE: 4fki_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f7n/4f7n_lig_3.xyz'
# code, len 4f7n 2
#
# DF SIZE: 4f7n_lig_1 1
# DF SIZE: 4f7n_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f6u/4f6u_lig_2.xyz'
# code, len 4f6u 1
#
# DF SIZE: 4f6u_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f6w/4f6w_lig_2.xyz'
# code, len 4f6w 1
#
# DF SIZE: 4f6w_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f7l/4f7l_lig_2.xyz'
# code, len 4f7l 1
#
# DF SIZE: 4f7l_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5eqy/5eqy_lig_8.xyz'
# code, len 5eqy 7
#
# DF SIZE: 5eqy_lig_1 1
# DF SIZE: 5eqy_lig_2 1
# DF SIZE: 5eqy_lig_3 1
# DF SIZE: 5eqy_lig_4 1
# DF SIZE: 5eqy_lig_5 1
# DF SIZE: 5eqy_lig_6 1
# DF SIZE: 5eqy_lig_7 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1nfx/1nfx_lig_5.xyz'
# code, len 1nfx 4
#
# DF SIZE: 1nfx_lig_1 1
# DF SIZE: 1nfx_lig_2 1
# DF SIZE: 1nfx_lig_3 1
# DF SIZE: 1nfx_lig_4 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4z9g/4z9g_lig_27.xyz'
# code, len 4z9g 26
#
# DF SIZE: 4z9g_lig_1 1
# DF SIZE: 4z9g_lig_2 1
# DF SIZE: 4z9g_lig_3 1
# DF SIZE: 4z9g_lig_4 1
# DF SIZE: 4z9g_lig_5 1
# DF SIZE: 4z9g_lig_6 1
# DF SIZE: 4z9g_lig_7 1
# DF SIZE: 4z9g_lig_8 1
# DF SIZE: 4z9g_lig_9 1
# DF SIZE: 4z9g_lig_10 1
# DF SIZE: 4z9g_lig_11 1
# DF SIZE: 4z9g_lig_12 1
# DF SIZE: 4z9g_lig_13 1
# DF SIZE: 4z9g_lig_14 1
# DF SIZE: 4z9g_lig_15 1
# DF SIZE: 4z9g_lig_16 1
# DF SIZE: 4z9g_lig_17 1
# DF SIZE: 4z9g_lig_18 1
# DF SIZE: 4z9g_lig_19 1
# DF SIZE: 4z9g_lig_20 1
# DF SIZE: 4z9g_lig_21 1
# DF SIZE: 4z9g_lig_22 1
# DF SIZE: 4z9g_lig_23 1
# DF SIZE: 4z9g_lig_24 1
# DF SIZE: 4z9g_lig_25 1
# DF SIZE: 4z9g_lig_26 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1u73/1u73_lig_3.xyz'
# code, len 1u73 2
#
# DF SIZE: 1u73_lig_1 1
# DF SIZE: 1u73_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1u72/1u72_lig_3.xyz'
# code, len 1u72 2
#
# DF SIZE: 1u72_lig_1 1
# DF SIZE: 1u72_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1u74/1u74_lig_2.xyz'
# code, len 1u74 1
#
# DF SIZE: 1u74_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ekg/4ekg_lig_3.xyz'
# code, len 4ekg 2
#
# DF SIZE: 4ekg_lig_1 1
# DF SIZE: 4ekg_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4eki/4eki_lig_2.xyz'
# code, len 4eki 1
#
# DF SIZE: 4eki_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3qox/3qox_lig_2.xyz'
# code, len 3qox 1
#
# DF SIZE: 3qox_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3g0b/3g0b_lig_3.xyz'
# code, len 3g0b 2
#
# DF SIZE: 3g0b_lig_1 1
# DF SIZE: 3g0b_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2rgu/2rgu_lig_3.xyz'
# code, len 2rgu 2
#
# DF SIZE: 2rgu_lig_1 1
# DF SIZE: 2rgu_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3bjm/3bjm_lig_2.xyz'
# code, len 3bjm 1
#
# DF SIZE: 3bjm_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1x70/1x70_lig_2.xyz'
# code, len 1x70 1
#
# DF SIZE: 1x70_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3vjk/3vjk_lig_2.xyz'
# code, len 3vjk 1
#
# DF SIZE: 3vjk_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3w2t/3w2t_lig_2.xyz'
# code, len 3w2t 1
#
# DF SIZE: 3w2t_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1xkk/1xkk_lig_2.xyz'
# code, len 1xkk 1
#
# DF SIZE: 1xkk_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1qg6/1qg6_lig_2.xyz'
# code, len 1qg6 1
#
# DF SIZE: 1qg6_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4p5z/4p5z_lig_3.xyz'
# code, len 4p5z 2
#
# DF SIZE: 4p5z_lig_1 1
# DF SIZE: 4p5z_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2aay/2aay_lig_3.xyz'
# code, len 2aay 2
#
# DF SIZE: 2aay_lig_1 1
# DF SIZE: 2aay_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3nrc/3nrc_lig_6.xyz'
# code, len 3nrc 5
#
# DF SIZE: 3nrc_lig_1 1
# DF SIZE: 3nrc_lig_2 1
# DF SIZE: 3nrc_lig_3 1
# DF SIZE: 3nrc_lig_4 1
# DF SIZE: 3nrc_lig_5 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4no7/4no7_lig_3.xyz'
# code, len 4no7 2
#
# DF SIZE: 4no7_lig_1 1
# DF SIZE: 4no7_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3f9m/3f9m_lig_3.xyz'
# code, len 3f9m 2
#
# DF SIZE: 3f9m_lig_1 1
# DF SIZE: 3f9m_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1jyq/1jyq_lig_3.xyz'
# code, len 1jyq 2
#
# DF SIZE: 1jyq_lig_1 1
# DF SIZE: 1jyq_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ldo/3ldo_lig_2.xyz'
# code, len 3ldo 1
#
# DF SIZE: 3ldo_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ldp/3ldp_lig_8.xyz'
# code, len 3ldp 7
#
# DF SIZE: 3ldp_lig_1 1
# DF SIZE: 3ldp_lig_2 1
# DF SIZE: 3ldp_lig_3 1
# DF SIZE: 3ldp_lig_4 1
# DF SIZE: 3ldp_lig_5 1
# DF SIZE: 3ldp_lig_6 1
# DF SIZE: 3ldp_lig_7 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5uen/5uen_lig_12.xyz'
# code, len 5uen 11
#
# DF SIZE: 5uen_lig_1 1
# DF SIZE: 5uen_lig_2 1
# DF SIZE: 5uen_lig_3 1
# DF SIZE: 5uen_lig_4 1
# DF SIZE: 5uen_lig_5 1
# DF SIZE: 5uen_lig_6 1
# DF SIZE: 5uen_lig_7 1
# DF SIZE: 5uen_lig_8 1
# DF SIZE: 5uen_lig_9 1
# DF SIZE: 5uen_lig_10 1
# DF SIZE: 5uen_lig_11 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6fag/6fag_lig_3.xyz'
# code, len 6fag 2
#
# DF SIZE: 6fag_lig_1 1
# DF SIZE: 6fag_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6f3b/6f3b_lig_2.xyz'
# code, len 6f3b 1
#
# DF SIZE: 6f3b_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1czm/1czm_lig_4.xyz'
# code, len 1czm 3
#
# DF SIZE: 1czm_lig_1 1
# DF SIZE: 1czm_lig_2 1
# DF SIZE: 1czm_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5gmm/5gmm_lig_2.xyz'
# code, len 5gmm 1
#
# DF SIZE: 5gmm_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4wr7/4wr7_lig_3.xyz'
# code, len 4wr7 2
#
# DF SIZE: 4wr7_lig_1 1
# DF SIZE: 4wr7_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4qsi/4qsi_lig_4.xyz'
# code, len 4qsi 3
#
# DF SIZE: 4qsi_lig_1 1
# DF SIZE: 4qsi_lig_2 1
# DF SIZE: 4qsi_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3m98/3m98_lig_3.xyz'
# code, len 3m98 2
#
# DF SIZE: 3m98_lig_1 1
# DF SIZE: 3m98_lig_2 1

# %%
#BB12A

import numpy as np
import pandas as pd
from collections import namedtuple
from math import cos, pi, log10
from copy import copy, deepcopy
from sklearn.neighbors import KDTree
import os
from multiprocessing import Pool


Mol = namedtuple('Mol', ['symbols', 'coords', 'message'])

#symbols is a list of atomic name to be met in the pdb
#kdtrees - is a dictionary of the KD-trees for each element

PDB = namedtuple('PDB', ['symbols', 'kdtrees', 'coords'])


def read_xyz(filename):
    f = open(filename, 'r')
    data = f.readlines()
    f.close()
    message = data[1].rstrip("\n")
    symbols = []
    coords = np.array([]).reshape((0, 3)).astype(float)
    for item in data[2:]:
        if item[0] != "H":
            item = item.strip("\n")
            item = item.split(" ")
            item = list(filter(None, item))
            symbols.append(item[0])
            coords = np.concatenate((coords, np.array(item[1:]).reshape((1,3)).astype(float)), 0)
    mol = Mol(symbols = symbols, coords = coords, message = message)
    mol.coords.astype(float)
    return mol


def read_pdb(filename):
    f = open(filename, 'r')
    data = f.readlines()
    f.close()
    # retain only lines containing atomic coordinates
    data = [line.rstrip("\n") for line in data if line.startswith("ATOM")]    
    symbols = ['Cb', 'Ob', 'Nb', 'Cs', 'Os', 'Ns', 'Ss']
    coords = {'Cb': [], 'Ob': [], 'Nb': [], 'Cs': [], 'Os': [], 'Ns': [], 'Ss': []}
    # read and keep coordinate per atom type
    for line in data:
        x = float(line[30:37])
        y = float(line[38:45])
        z = float(line[46:53])

        symbol = deepcopy(line[12:16]).strip()          
    
        if symbol in ['C', 'CA', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9']:
            coords['Cb'].append([x, y, z])
       
        elif symbol in ['O', 'OA', 'O1', 'O2', 'O3', 'O4', 'O5', 'O6', 'O7', 'O8', 'O9', 'OXT']:
            coords['Ob'].append([x, y, z])
        
        elif symbol in ['N', 'NA', 'N1', 'N2', 'N3', 'N4', 'N5', 'N6', 'N7', 'N8', 'N9']:
            coords['Nb'].append([x, y, z])
         
        elif symbol in ['CB','CB1','CB2','CB3','CB4','CB5','CB6','CB7','CB8','CB9','CG','CG1','CG2','CG3','CG4','CG5','CG6','CG7','CG8','CG9','CD','CD1','CD2','CD3','CD4','CD5','CD6','CD7','CD8','CD9','CE','CE1','CE2','CE3','CE4','CE5','CE6','CE7','CE8','CE9','CZ','CZ1','CZ2','CZ3','CZ4','CZ5','CZ6','CZ7','CZ8','CZ9','CH','CH1','CH2','CH3','CH4','CH5','CH6','CH7','CH8','CH9']:
            coords['Cs'].append([x, y, z])
        
        elif symbol in ['OB','OB1','OB2','OB3','OB4','OB5','OB6','OB7','OB8','OB9','OG','OG1','OG2','OG3','OG4','OG5','OG6','OG7','OG8','OG9','OD','OD1','OD2','OD3','OD4','OD5','OD6','OD7','OD8','OD9','OE','OE1','OE2','OE3','OE4','OE5','OE6','OE7','OE8','OE9','OZ','OZ1','OZ2','OZ3','OZ4','OZ5','OZ6','OZ7','OZ8','OZ9','OH','OH1','OH2','OH3','OH4','OH5','OH6','OH7','OH8','OH9']:
            coords['Os'].append([x, y, z])
        
        elif symbol in ['NB','NB1','NB2','NB3','NB4','NB5','NB6','NB7','NB8','NB9','NG','NG1','NG2','NG3','NG4','NG5','NG6','NG7','NG8','NG9','ND','ND1','ND2','ND3','ND4','ND5','ND6','ND7','ND8','ND9','NE','NE1','NE2','NE3','NE4','NE5','NE6','NE7','NE8','NE9','NZ','NZ1','NZ2','NZ3','NZ4','NZ5','NZ6','NZ7','NZ8','NZ9','NH','NH1','NH2','NH3','NH4','NH5','NH6','NH7','NH8','NH9']:
            coords['Ns'].append([x, y, z])
        
        elif symbol in ['SB','SB1','SB2','SB3','SB4','SB5','SB6','SB7','SB8','SB9','SG','SG1','SG2','SG3','SG4','SG5','SG6','SG7','SG8','SG9','SD','SD1','SD2','SD3','SD4','SD5','SD6','SD7','SD8','SD9','SE','SE1','SE2','SE3','SE4','SE5','SE6','SE7','SE8','SE9','SZ','SZ1','SZ2','SZ3','SZ4','SZ5','SZ6','SZ7','SZ8','SZ9','SH','SH1','SH2','SH3','SH4','SH5','SH6','SH7','SH8','SH9', 'S']:
            coords['Ss'].append([x, y, z])
        
        elif symbol == 'SE':
            coords['Ss'].append([x, y, z])
        
        elif symbol in ['LI', 'NA', 'K', 'RB', 'CS', 'AU', 'BA', 'CA', 'CD', 'SR', 'BE', 'CO', 'MG', 'CU', 'FE', 'HG', 'MN', 'NI', 'ZN']:
            continue
        
        elif symbol.strip()[0] == 'H':
            continue
        
        else:
            print(symbol, line[:])
            raise ValueError("Unknown atomic symbol in pdb")

    kdtrees = {}

    # create a dict of KD trees
    for atom_type in symbols:
        coords[atom_type] = np.array(coords[atom_type])
        if len(coords[atom_type]) != 0:
            kdtrees[atom_type] = KDTree(coords[atom_type], leaf_size=10)

    mol = PDB(symbols=symbols, kdtrees=kdtrees, coords=coords)

    return mol

 
     

def BB_desc(mol, pdb):

    desc = [0.] * 63
    for atom_type in pdb.coords.keys():
        # check if the atom is in the structure
        # if not add zeros for the vector
        if len(pdb.coords[atom_type]) != 0:
            ind = pdb.kdtrees[atom_type].query_radius(mol.coords, r = 12)

            atom_type_list = []
            for i in range(mol.coords.shape[0]):
                
                atom_env_coords = pdb.coords[atom_type][ind[i], :]
                atom_lig_coords = mol.coords[i]
                
                #print(atom_type, mol.symbols[i], len(ind[i]))
                
                if atom_type == "Cb":
                    if mol.symbols[i] == "C":
                        desc[0] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[1] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[2] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[3] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[4] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[5] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[6] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[7] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[8] += len(ind[i])
                elif atom_type == "Ob":
                    if mol.symbols[i] == "C":
                        desc[9] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[10] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[11] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[12] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[13] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[14] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[15] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[16] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[17] += len(ind[i])
                elif atom_type == "Nb":
                    if mol.symbols[i] == "C":
                        desc[18] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[19] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[20] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[21] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[22] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[23] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[24] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[25] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[26] += len(ind[i])
                elif atom_type == "Cs":
                    if mol.symbols[i] == "C":
                        desc[27] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[28] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[29] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[30] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[31] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[32] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[33] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[34] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[35] += len(ind[i])
                elif atom_type == "Os":
                    if mol.symbols[i] == "C":
                        desc[36] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[37] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[38] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[39] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[40] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[41] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[42] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[43] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[44] += len(ind[i])
                elif atom_type == "Ns":
                    if mol.symbols[i] == "C":
                        desc[45] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[46] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[47] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[48] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[49] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[50] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[51] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[52] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[53] += len(ind[i])
                elif atom_type == "Ss":
                    if mol.symbols[i] == "C":
                        desc[54] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[55] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[56] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[57] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[58] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[59] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[60] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[61] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[62] += len(ind[i])
    return desc

def compute(pdb_id):
    desc_arr = []
    mol_names_arr = []
    for i in range(1, 100):
        try:
            mol_names_arr.append(pdb_id + "_lig_{}".format(i))
            #print(pdb_id, "molnamesarr", mol_names_arr[0])
            mol = read_xyz("./all/" + pdb_id + "/" + pdb_id + "_lig_{}.xyz".format(i))
            pdb = read_pdb("./all/" + pdb_id + "/" + pdb_id + "_prot_1.pdb")

            desc = BB_desc(mol, pdb)
            desc_arr.append(desc)
            
        except Exception as e:
            print("COMPUTE FINISHED")
            break
    return desc_arr, mol_names_arr


def main(): 
    data = pd.read_csv("./index_all.csv")
    codes = [code for code in list(Counter(data.docked_pdb).keys()) if len(code) == 4]
    X = []
    y = []

    try:
        for code in codes:
            desc_arr, mol_names_arr = compute(code)
            print("code, len", code, len(desc_arr), '\n')
            if desc_arr is not None:
                for desc_idx in range(len(desc_arr)):
                    desc_i = desc_arr[desc_idx]
                    mol_name_cur = mol_names_arr[desc_idx]
                    #print("DF SIZE:", mol_name_cur, len(data[data.pose_filename == mol_name_cur]))
                    X.append(desc_i)
                    y.append(-log10(data[data.pose_filename == mol_name_cur].koff_s.iloc[0]))
                    #print(desc_i, data[data.pose_filename == mol_name_cur].koff_s.iloc[0])
            else:
                X.append(desc_i)
                y.append(-log10(data[data.pose_filename == mol_name_cur].koff_s.iloc[0]))
                #print(desc_i, data[data.pose_filename == mol_name_cur].koff_s.iloc[0])
    except Exception as e:
        print("error in ", code, mol_name_cur,e)

    X = np.array(X).astype(int)
    y = np.array(y)

    np.save("bb_X_all.npy", X)
    np.save("bb_y_all.npy", y)
        

if __name__ == "__main__":
    main()
# Out:
# COMPUTE FINISHED
# code, len 1xal 3
#
# COMPUTE FINISHED
# code, len 2yme 1
#
# COMPUTE FINISHED
# code, len 3uzc 10
#
# COMPUTE FINISHED
# code, len 4ug2 1
#
# COMPUTE FINISHED
# code, len 2ydv 5
#
# COMPUTE FINISHED
# code, len 3qak 1
#
# COMPUTE FINISHED
# code, len 3iar 1
#
# COMPUTE FINISHED
# code, len 5iz6 1
#
# COMPUTE FINISHED
# code, len 5z8h 1
#
# COMPUTE FINISHED
# code, len 1kvl 3
#
# COMPUTE FINISHED
# code, len 4wbg 1
#
# COMPUTE FINISHED
# code, len 2pu4 2
#
# COMPUTE FINISHED
# code, len 4ksq 1
#
# COMPUTE FINISHED
# code, len 4ksp 1
#
# COMPUTE FINISHED
# code, len 6gpx 2
#
# COMPUTE FINISHED
# code, len 4ek4 1
#
# COMPUTE FINISHED
# code, len 4ek6 1
#
# COMPUTE FINISHED
# code, len 4fkj 1
#
# COMPUTE FINISHED
# code, len 4ek8 5
#
# COMPUTE FINISHED
# code, len 3sw4 1
#
# COMPUTE FINISHED
# code, len 3sw7 1
#
# COMPUTE FINISHED
# code, len 4ek5 2
#
# COMPUTE FINISHED
# code, len 4fko 1
#
# COMPUTE FINISHED
# code, len 4fkp 1
#
# COMPUTE FINISHED
# code, len 4fkq 1
#
# COMPUTE FINISHED
# code, len 4fkr 2
#
# COMPUTE FINISHED
# code, len 4fks 1
#
# COMPUTE FINISHED
# code, len 4fkv 2
#
# COMPUTE FINISHED
# code, len 4fkt 1
#
# COMPUTE FINISHED
# code, len 4fku 1
#
# COMPUTE FINISHED
# code, len 4fkw 1
#
# COMPUTE FINISHED
# code, len 4fkg 1
#
# COMPUTE FINISHED
# code, len 4fki 1
#
# COMPUTE FINISHED
# code, len 4f7n 2
#
# COMPUTE FINISHED
# code, len 4f6u 1
#
# COMPUTE FINISHED
# code, len 4f6w 1
#
# COMPUTE FINISHED
# code, len 4f7l 1
#
# COMPUTE FINISHED
# code, len 5eqy 7
#
# COMPUTE FINISHED
# code, len 1nfx 4
#
# COMPUTE FINISHED
# code, len 4z9g 26
#
# COMPUTE FINISHED
# code, len 1u73 2
#
# COMPUTE FINISHED
# code, len 1u72 2
#
# COMPUTE FINISHED
# code, len 1u74 1
#
# COMPUTE FINISHED
# code, len 4ekg 2
#
# COMPUTE FINISHED
# code, len 4eki 1
#
# COMPUTE FINISHED
# code, len 3qox 1
#
# COMPUTE FINISHED
# code, len 3g0b 2
#
# COMPUTE FINISHED
# code, len 2rgu 2
#
# COMPUTE FINISHED
# code, len 3bjm 1
#
# COMPUTE FINISHED
# code, len 1x70 1
#
# COMPUTE FINISHED
# code, len 3vjk 1
#
# COMPUTE FINISHED
# code, len 3w2t 1
#
# COMPUTE FINISHED
# code, len 1xkk 1
#
# COMPUTE FINISHED
# code, len 1qg6 1
#
# COMPUTE FINISHED
# code, len 4p5z 2
#
# COMPUTE FINISHED
# code, len 2aay 2
#
# COMPUTE FINISHED
# code, len 3nrc 5
#
# COMPUTE FINISHED
# code, len 4no7 2
#
# COMPUTE FINISHED
# code, len 3f9m 2
#
# COMPUTE FINISHED
# code, len 1jyq 2
#
# COMPUTE FINISHED
# code, len 3ldo 1
#
# COMPUTE FINISHED
# code, len 3ldp 7
#
# COMPUTE FINISHED
# code, len 5uen 11
#
# COMPUTE FINISHED
# code, len 6fag 2
#
# COMPUTE FINISHED
# code, len 6f3b 1
#
# COMPUTE FINISHED
# code, len 1czm 3
#
# COMPUTE FINISHED
# code, len 5gmm 1
#
# COMPUTE FINISHED
# code, len 4wr7 2
#
# COMPUTE FINISHED
# code, len 4qsi 3
#
# COMPUTE FINISHED
# code, len 3m98 2
#
# COMPUTE FINISHED
# code, len 4knj 3
#
# COMPUTE FINISHED
# code, len 3sbi 2
#
# COMPUTE FINISHED
# code, len 3s9t 1
#
# COMPUTE FINISHED
# code, len 5ll4 1
#
# COMPUTE FINISHED
# code, len 5fl5 7
#
# COMPUTE FINISHED
# code, len 6fe0 8
#
# COMPUTE FINISHED
# code, len 6h37 13
#
# COMPUTE FINISHED
# code, len 5ll5 2
#
# COMPUTE FINISHED
# code, len 5ll9 3
#
# COMPUTE FINISHED
# code, len 4kp5 2
#
# COMPUTE FINISHED
# code, len 6g7a 2
#
# COMPUTE FINISHED
# code, len 4qjo 4
#
# COMPUTE FINISHED
# code, len 4qjw 1
#
# COMPUTE FINISHED
# code, len 3p8o 1
#
# COMPUTE FINISHED
# code, len 3p8n 1
#
# COMPUTE FINISHED
# code, len 4dru 8
#
# COMPUTE FINISHED
# code, len 3rze 1
#
# COMPUTE FINISHED
# code, len 1qbs 2
#
# COMPUTE FINISHED
# code, len 1ebw 12
#
# COMPUTE FINISHED
# code, len 1ajv 4
#
# COMPUTE FINISHED
# code, len 4njv 2
#
# COMPUTE FINISHED
# code, len 1ec2 6
#
# COMPUTE FINISHED
# code, len 3ekv 1
#
# COMPUTE FINISHED
# code, len 1d4h 5
#
# COMPUTE FINISHED
# code, len 1eby 1
#
# COMPUTE FINISHED
# code, len 1ebz 1
#
# COMPUTE FINISHED
# code, len 1ec1 1
#
# COMPUTE FINISHED
# code, len 1d4i 1
#
# COMPUTE FINISHED
# code, len 3ekx 1
#
# COMPUTE FINISHED
# code, len 1hxw 1
#
# COMPUTE FINISHED
# code, len 1hiv 1
#
# COMPUTE FINISHED
# code, len 1ikw 1
#
# COMPUTE FINISHED
# code, len 2uwd 1
#
# COMPUTE FINISHED
# code, len 2bsm 4
#
# COMPUTE FINISHED
# code, len 5j2x 1
#
# COMPUTE FINISHED
# code, len 6f1n 1
#
# COMPUTE FINISHED
# code, len 6elo 2
#
# COMPUTE FINISHED
# code, len 5j64 4
#
# COMPUTE FINISHED
# code, len 6eln 1
#
# COMPUTE FINISHED
# code, len 5j20 2
#
# COMPUTE FINISHED
# code, len 5j86 8
#
# COMPUTE FINISHED
# code, len 5j9x 4
#
# COMPUTE FINISHED
# code, len 6elp 3
#
# COMPUTE FINISHED
# code, len 5j27 1
#
# COMPUTE FINISHED
# code, len 5j82 2
#
# COMPUTE FINISHED
# code, len 5lrz 1
#
# COMPUTE FINISHED
# code, len 5lr7 1
#
# COMPUTE FINISHED
# code, len 2yki 1
#
# COMPUTE FINISHED
# code, len 5lq9 1
#
# COMPUTE FINISHED
# code, len 5ls1 1
#
# COMPUTE FINISHED
# code, len 5t21 1
#
# COMPUTE FINISHED
# code, len 6eya 1
#
# COMPUTE FINISHED
# code, len 5lo6 1
#
# COMPUTE FINISHED
# code, len 5lnz 1
#
# COMPUTE FINISHED
# code, len 6ey8 1
#
# COMPUTE FINISHED
# code, len 4efu 1
#
# COMPUTE FINISHED
# code, len 6ey9 1
#
# COMPUTE FINISHED
# code, len 6eyb 1
#
# COMPUTE FINISHED
# code, len 5oci 11
#
# COMPUTE FINISHED
# code, len 5odx 2
#
# COMPUTE FINISHED
# code, len 5nyh 3
#
# COMPUTE FINISHED
# code, len 5od7 7
#
# COMPUTE FINISHED
# code, len 6ei5 1
#
# COMPUTE FINISHED
# code, len 5lr1 2
#
# COMPUTE FINISHED
# code, len 6el5 1
#
# COMPUTE FINISHED
# code, len 5lo5 1
#
# COMPUTE FINISHED
# code, len 2ykj 1
#
# COMPUTE FINISHED
# code, len 5lny 24
#
# COMPUTE FINISHED
# code, len 4yay 2
#
# COMPUTE FINISHED
# code, len 6hlo 1
#
# COMPUTE FINISHED
# code, len 2nv6 1
#
# COMPUTE FINISHED
# code, len 2x22 1
#
# COMPUTE FINISHED
# code, len 2aqi 1
#
# COMPUTE FINISHED
# code, len 4iqk 1
#
# COMPUTE FINISHED
# code, len 5h0u 3
#
# COMPUTE FINISHED
# code, len 1hov 3
#
# COMPUTE FINISHED
# code, len 2ow1 3
#
# COMPUTE FINISHED
# code, len 5zhp 9
#
# COMPUTE FINISHED
# code, len 1kv1 2
#
# COMPUTE FINISHED
# code, len 1kv2 15
#
# COMPUTE FINISHED
# code, len 3zs5 1
#
# COMPUTE FINISHED
# code, len 3hll 1
#
# COMPUTE FINISHED
# code, len 5mtx 8
#
# COMPUTE FINISHED
# code, len 1oz1 1
#
# COMPUTE FINISHED
# code, len 5if1 3
#
# COMPUTE FINISHED
# code, len 1w98 3
#
# COMPUTE FINISHED
# code, len 3ddu 3
#
# COMPUTE FINISHED
# code, len 1bil 7
#
# COMPUTE FINISHED
# code, len 2v0z 1
#
# COMPUTE FINISHED
# code, len 6c4d 33
#
# COMPUTE FINISHED
# code, len 4ocz 1
#
# COMPUTE FINISHED
# code, len 4od0 19
#
# COMPUTE FINISHED
# code, len 5l8p 1
#
# COMPUTE FINISHED
# code, len 5l41 1
#
# COMPUTE FINISHED
# code, len 5l3u 1
#
# COMPUTE FINISHED
# code, len 2mgy 6
#
# COMPUTE FINISHED
# code, len 4wa4 1

# %%
#BBC12A

import numpy as np
import pandas as pd
from collections import namedtuple
from math import cos, pi, log10
from copy import copy, deepcopy
from sklearn.neighbors import KDTree
import os
from multiprocessing import Pool


Mol = namedtuple('Mol', ['symbols', 'coords', 'message'])

#symbols is a list of atomic name to be met in the pdb
#kdtrees - is a dictionary of the KD-trees for each element

PDB = namedtuple('PDB', ['symbols', 'kdtrees', 'coords'])


def read_xyz(filename):
    f = open(filename, 'r')
    data = f.readlines()
    f.close()
    message = data[1].rstrip("\n")
    symbols = []
    coords = np.array([]).reshape((0, 3)).astype(float)
    for item in data[2:]:
        if item[0] != "H":
            item = item.strip("\n")
            item = item.split(" ")
            item = list(filter(None, item))
            symbols.append(item[0])
            coords = np.concatenate((coords, np.array(item[1:]).reshape((1,3)).astype(float)), 0)
    mol = Mol(symbols = symbols, coords = coords, message = message)
    mol.coords.astype(float)
    return mol


def read_pdb(filename):
    f = open(filename, 'r')
    data = f.readlines()
    f.close()
    # retain only lines containing atomic coordinates
    data = [line.rstrip("\n") for line in data if line.startswith("ATOM")]    
    symbols = ['Cb', 'Ob', 'Nb', 'Cs', 'Os', 'Ns', 'Ss']
    coords = {'Cb': [], 'Ob': [], 'Nb': [], 'Cs': [], 'Os': [], 'Ns': [], 'Ss': []}
    # read and keep coordinate per atom type
    for line in data:
        x = float(line[30:37])
        y = float(line[38:45])
        z = float(line[46:53])

        symbol = deepcopy(line[12:16]).strip()          
    
        if symbol in ['C', 'CA', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9']:
            coords['Cb'].append([x, y, z])
       
        elif symbol in ['O', 'OA', 'O1', 'O2', 'O3', 'O4', 'O5', 'O6', 'O7', 'O8', 'O9', 'OXT']:
            coords['Ob'].append([x, y, z])
        
        elif symbol in ['N', 'NA', 'N1', 'N2', 'N3', 'N4', 'N5', 'N6', 'N7', 'N8', 'N9']:
            coords['Nb'].append([x, y, z])
         
        elif symbol in ['CB','CB1','CB2','CB3','CB4','CB5','CB6','CB7','CB8','CB9','CG','CG1','CG2','CG3','CG4','CG5','CG6','CG7','CG8','CG9','CD','CD1','CD2','CD3','CD4','CD5','CD6','CD7','CD8','CD9','CE','CE1','CE2','CE3','CE4','CE5','CE6','CE7','CE8','CE9','CZ','CZ1','CZ2','CZ3','CZ4','CZ5','CZ6','CZ7','CZ8','CZ9','CH','CH1','CH2','CH3','CH4','CH5','CH6','CH7','CH8','CH9']:
            coords['Cs'].append([x, y, z])
        
        elif symbol in ['OB','OB1','OB2','OB3','OB4','OB5','OB6','OB7','OB8','OB9','OG','OG1','OG2','OG3','OG4','OG5','OG6','OG7','OG8','OG9','OD','OD1','OD2','OD3','OD4','OD5','OD6','OD7','OD8','OD9','OE','OE1','OE2','OE3','OE4','OE5','OE6','OE7','OE8','OE9','OZ','OZ1','OZ2','OZ3','OZ4','OZ5','OZ6','OZ7','OZ8','OZ9','OH','OH1','OH2','OH3','OH4','OH5','OH6','OH7','OH8','OH9']:
            coords['Os'].append([x, y, z])
        
        elif symbol in ['NB','NB1','NB2','NB3','NB4','NB5','NB6','NB7','NB8','NB9','NG','NG1','NG2','NG3','NG4','NG5','NG6','NG7','NG8','NG9','ND','ND1','ND2','ND3','ND4','ND5','ND6','ND7','ND8','ND9','NE','NE1','NE2','NE3','NE4','NE5','NE6','NE7','NE8','NE9','NZ','NZ1','NZ2','NZ3','NZ4','NZ5','NZ6','NZ7','NZ8','NZ9','NH','NH1','NH2','NH3','NH4','NH5','NH6','NH7','NH8','NH9']:
            coords['Ns'].append([x, y, z])
        
        elif symbol in ['SB','SB1','SB2','SB3','SB4','SB5','SB6','SB7','SB8','SB9','SG','SG1','SG2','SG3','SG4','SG5','SG6','SG7','SG8','SG9','SD','SD1','SD2','SD3','SD4','SD5','SD6','SD7','SD8','SD9','SE','SE1','SE2','SE3','SE4','SE5','SE6','SE7','SE8','SE9','SZ','SZ1','SZ2','SZ3','SZ4','SZ5','SZ6','SZ7','SZ8','SZ9','SH','SH1','SH2','SH3','SH4','SH5','SH6','SH7','SH8','SH9', 'S']:
            coords['Ss'].append([x, y, z])
        
        elif symbol == 'SE':
            coords['Ss'].append([x, y, z])
        
        elif symbol in ['LI', 'NA', 'K', 'RB', 'CS', 'AU', 'BA', 'CA', 'CD', 'SR', 'BE', 'CO', 'MG', 'CU', 'FE', 'HG', 'MN', 'NI', 'ZN']:
            continue
        
        elif symbol.strip()[0] == 'H':
            continue
        
        else:
            print(symbol, line[:])
            raise ValueError("Unknown atomic symbol in pdb")

    kdtrees = {}

    # create a dict of KD trees
    for atom_type in symbols:
        coords[atom_type] = np.array(coords[atom_type])
        if len(coords[atom_type]) != 0:
            kdtrees[atom_type] = KDTree(coords[atom_type], leaf_size=10)

    mol = PDB(symbols=symbols, kdtrees=kdtrees, coords=coords)

    return mol

 
     

def BB_desc(mol, pdb):

    desc = [0.] * 7
    for atom_type in pdb.coords.keys():
        # check if the atom is in the structure
        # if not add zeros for the vector
        if len(pdb.coords[atom_type]) != 0:
            ind = pdb.kdtrees[atom_type].query_radius(mol.coords, r = 12)

            atom_type_list = []
            for i in range(mol.coords.shape[0]):
                
                atom_env_coords = pdb.coords[atom_type][ind[i], :]
                atom_lig_coords = mol.coords[i]
                
                #print(atom_type, mol.symbols[i], len(ind[i]))
                
                if atom_type == "Cb":
                    if mol.symbols[i] == "C":
                        desc[0] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[0] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[0] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[0] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[0] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[0] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[0] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[0] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[0] += len(ind[i])
                elif atom_type == "Ob":
                    if mol.symbols[i] == "C":
                        desc[1] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[1] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[1] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[1] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[1] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[1] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[1] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[1] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[1] += len(ind[i])
                elif atom_type == "Nb":
                    if mol.symbols[i] == "C":
                        desc[2] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[2] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[2] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[2] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[2] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[2] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[2] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[2] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[2] += len(ind[i])
                elif atom_type == "Cs":
                    if mol.symbols[i] == "C":
                        desc[3] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[3] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[3] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[3] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[3] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[3] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[3] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[3] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[3] += len(ind[i])
                elif atom_type == "Os":
                    if mol.symbols[i] == "C":
                        desc[4] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[4] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[4] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[4] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[4] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[4] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[4] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[4] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[4] += len(ind[i])
                elif atom_type == "Ns":
                    if mol.symbols[i] == "C":
                        desc[5] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[5] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[5] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[5] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[5] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[5] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[5] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[5] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[5] += len(ind[i])
                elif atom_type == "Ss":
                    if mol.symbols[i] == "C":
                        desc[6] += len(ind[i])
                    elif mol.symbols[i] == "O":
                        desc[6] += len(ind[i])
                    elif mol.symbols[i] == "N":
                        desc[6] += len(ind[i])
                    elif mol.symbols[i] == "S":
                        desc[6] += len(ind[i])
                    elif mol.symbols[i] == "P":
                        desc[6] += len(ind[i])
                    elif mol.symbols[i] == "F":
                        desc[6] += len(ind[i])
                    elif mol.symbols[i] == "Cl":
                        desc[6] += len(ind[i])
                    elif mol.symbols[i] == "Br":
                        desc[6] += len(ind[i])
                    elif mol.symbols[i] == "I":
                        desc[6] += len(ind[i])
    return desc

def compute(pdb_id):
    desc_arr = []
    mol_names_arr = []
    for i in range(1, 100):
        try:
            mol_names_arr.append(pdb_id + "_lig_{}".format(i))
            #print(pdb_id, "molnamesarr", mol_names_arr[0])
            mol = read_xyz("./all/" + pdb_id + "/" + pdb_id + "_lig_{}.xyz".format(i))
            pdb = read_pdb("./all/" + pdb_id + "/" + pdb_id + "_prot_1.pdb")

            desc = BB_desc(mol, pdb)
            desc_arr.append(desc)
            
        except Exception as e:
            print("COMPUTE FINISHED")
            break
    return desc_arr, mol_names_arr


def main(): 
    data = pd.read_csv("./index_all.csv")
    codes = [code for code in list(Counter(data.docked_pdb).keys()) if len(code) == 4]
    X = []
    y = []

    try:
        for code in codes:
            desc_arr, mol_names_arr = compute(code)
            print("code, len", code, len(desc_arr), '\n')
            if desc_arr is not None:
                for desc_idx in range(len(desc_arr)):
                    desc_i = desc_arr[desc_idx]
                    mol_name_cur = mol_names_arr[desc_idx]
                    #print("DF SIZE:", mol_name_cur, len(data[data.pose_filename == mol_name_cur]))
                    X.append(desc_i)
                    y.append(-log10(data[data.pose_filename == mol_name_cur].koff_s.iloc[0]))
                    #print(desc_i, data[data.pose_filename == mol_name_cur].koff_s.iloc[0])
            else:
                X.append(desc_i)
                y.append(-log10(data[data.pose_filename == mol_name_cur].koff_s.iloc[0]))
                #print(desc_i, data[data.pose_filename == mol_name_cur].koff_s.iloc[0])
    except Exception as e:
        print("error in ", code, mol_name_cur,e)

    X = np.array(X).astype(int)
    y = np.array(y)

    np.save("bbc_X_all.npy", X)
    np.save("bbc_y_all.npy", y)
        

if __name__ == "__main__":
    main()
# Out:
# COMPUTE FINISHED
# code, len 1xal 3
#
# COMPUTE FINISHED
# code, len 2yme 1
#
# COMPUTE FINISHED
# code, len 3uzc 10
#
# COMPUTE FINISHED
# code, len 4ug2 1
#
# COMPUTE FINISHED
# code, len 2ydv 5
#
# COMPUTE FINISHED
# code, len 3qak 1
#
# COMPUTE FINISHED
# code, len 3iar 1
#
# COMPUTE FINISHED
# code, len 5iz6 1
#
# COMPUTE FINISHED
# code, len 5z8h 1
#
# COMPUTE FINISHED
# code, len 1kvl 3
#
# COMPUTE FINISHED
# code, len 4wbg 1
#
# COMPUTE FINISHED
# code, len 2pu4 2
#
# COMPUTE FINISHED
# code, len 4ksq 1
#
# COMPUTE FINISHED
# code, len 4ksp 1
#
# COMPUTE FINISHED
# code, len 6gpx 2
#
# COMPUTE FINISHED
# code, len 4ek4 1
#
# COMPUTE FINISHED
# code, len 4ek6 1
#
# COMPUTE FINISHED
# code, len 4fkj 1
#
# COMPUTE FINISHED
# code, len 4ek8 5
#
# COMPUTE FINISHED
# code, len 3sw4 1
#
# COMPUTE FINISHED
# code, len 3sw7 1
#
# COMPUTE FINISHED
# code, len 4ek5 2
#
# COMPUTE FINISHED
# code, len 4fko 1
#
# COMPUTE FINISHED
# code, len 4fkp 1
#
# COMPUTE FINISHED
# code, len 4fkq 1
#
# COMPUTE FINISHED
# code, len 4fkr 2
#
# COMPUTE FINISHED
# code, len 4fks 1
#
# COMPUTE FINISHED
# code, len 4fkv 2
#
# COMPUTE FINISHED
# code, len 4fkt 1
#
# COMPUTE FINISHED
# code, len 4fku 1
#
# COMPUTE FINISHED
# code, len 4fkw 1
#
# COMPUTE FINISHED
# code, len 4fkg 1
#
# COMPUTE FINISHED
# code, len 4fki 1
#
# COMPUTE FINISHED
# code, len 4f7n 2
#
# COMPUTE FINISHED
# code, len 4f6u 1
#
# COMPUTE FINISHED
# code, len 4f6w 1
#
# COMPUTE FINISHED
# code, len 4f7l 1
#
# COMPUTE FINISHED
# code, len 5eqy 7
#
# COMPUTE FINISHED
# code, len 1nfx 4
#
# COMPUTE FINISHED
# code, len 4z9g 26
#
# COMPUTE FINISHED
# code, len 1u73 2
#
# COMPUTE FINISHED
# code, len 1u72 2
#
# COMPUTE FINISHED
# code, len 1u74 1
#
# COMPUTE FINISHED
# code, len 4ekg 2
#
# COMPUTE FINISHED
# code, len 4eki 1
#
# COMPUTE FINISHED
# code, len 3qox 1
#
# COMPUTE FINISHED
# code, len 3g0b 2
#
# COMPUTE FINISHED
# code, len 2rgu 2
#
# COMPUTE FINISHED
# code, len 3bjm 1
#
# COMPUTE FINISHED
# code, len 1x70 1
#
# COMPUTE FINISHED
# code, len 3vjk 1
#
# COMPUTE FINISHED
# code, len 3w2t 1
#
# COMPUTE FINISHED
# code, len 1xkk 1
#
# COMPUTE FINISHED
# code, len 1qg6 1
#
# COMPUTE FINISHED
# code, len 4p5z 2
#
# COMPUTE FINISHED
# code, len 2aay 2
#
# COMPUTE FINISHED
# code, len 3nrc 5
#
# COMPUTE FINISHED
# code, len 4no7 2
#
# COMPUTE FINISHED
# code, len 3f9m 2
#
# COMPUTE FINISHED
# code, len 1jyq 2
#
# COMPUTE FINISHED
# code, len 3ldo 1
#
# COMPUTE FINISHED
# code, len 3ldp 7
#
# COMPUTE FINISHED
# code, len 5uen 11
#
# COMPUTE FINISHED
# code, len 6fag 2
#
# COMPUTE FINISHED
# code, len 6f3b 1
#
# COMPUTE FINISHED
# code, len 1czm 3
#
# COMPUTE FINISHED
# code, len 5gmm 1
#
# COMPUTE FINISHED
# code, len 4wr7 2
#
# COMPUTE FINISHED
# code, len 4qsi 3
#
# COMPUTE FINISHED
# code, len 3m98 2
#
# COMPUTE FINISHED
# code, len 4knj 3
#
# COMPUTE FINISHED
# code, len 3sbi 2
#
# COMPUTE FINISHED
# code, len 3s9t 1
#
# COMPUTE FINISHED
# code, len 5ll4 1
#
# COMPUTE FINISHED
# code, len 5fl5 7
#
# COMPUTE FINISHED
# code, len 6fe0 8
#
# COMPUTE FINISHED
# code, len 6h37 13
#
# COMPUTE FINISHED
# code, len 5ll5 2
#
# COMPUTE FINISHED
# code, len 5ll9 3
#
# COMPUTE FINISHED
# code, len 4kp5 2
#
# COMPUTE FINISHED
# code, len 6g7a 2
#
# COMPUTE FINISHED
# code, len 4qjo 4
#
# COMPUTE FINISHED
# code, len 4qjw 1
#
# COMPUTE FINISHED
# code, len 3p8o 1
#
# COMPUTE FINISHED
# code, len 3p8n 1
#
# COMPUTE FINISHED
# code, len 4dru 8
#
# COMPUTE FINISHED
# code, len 3rze 1
#
# COMPUTE FINISHED
# code, len 1qbs 2
#
# COMPUTE FINISHED
# code, len 1ebw 12
#
# COMPUTE FINISHED
# code, len 1ajv 4
#
# COMPUTE FINISHED
# code, len 4njv 2
#
# COMPUTE FINISHED
# code, len 1ec2 6
#
# COMPUTE FINISHED
# code, len 3ekv 1
#
# COMPUTE FINISHED
# code, len 1d4h 5
#
# COMPUTE FINISHED
# code, len 1eby 1
#
# COMPUTE FINISHED
# code, len 1ebz 1
#
# COMPUTE FINISHED
# code, len 1ec1 1
#
# COMPUTE FINISHED
# code, len 1d4i 1
#
# COMPUTE FINISHED
# code, len 3ekx 1
#
# COMPUTE FINISHED
# code, len 1hxw 1
#
# COMPUTE FINISHED
# code, len 1hiv 1
#
# COMPUTE FINISHED
# code, len 1ikw 1
#
# COMPUTE FINISHED
# code, len 2uwd 1
#
# COMPUTE FINISHED
# code, len 2bsm 4
#
# COMPUTE FINISHED
# code, len 5j2x 1
#
# COMPUTE FINISHED
# code, len 6f1n 1
#
# COMPUTE FINISHED
# code, len 6elo 2
#
# COMPUTE FINISHED
# code, len 5j64 4
#
# COMPUTE FINISHED
# code, len 6eln 1
#
# COMPUTE FINISHED
# code, len 5j20 2
#
# COMPUTE FINISHED
# code, len 5j86 8
#
# COMPUTE FINISHED
# code, len 5j9x 4
#
# COMPUTE FINISHED
# code, len 6elp 3
#
# COMPUTE FINISHED
# code, len 5j27 1
#
# COMPUTE FINISHED
# code, len 5j82 2
#
# COMPUTE FINISHED
# code, len 5lrz 1
#
# COMPUTE FINISHED
# code, len 5lr7 1
#
# COMPUTE FINISHED
# code, len 2yki 1
#
# COMPUTE FINISHED
# code, len 5lq9 1
#
# COMPUTE FINISHED
# code, len 5ls1 1
#
# COMPUTE FINISHED
# code, len 5t21 1
#
# COMPUTE FINISHED
# code, len 6eya 1
#
# COMPUTE FINISHED
# code, len 5lo6 1
#
# COMPUTE FINISHED
# code, len 5lnz 1
#
# COMPUTE FINISHED
# code, len 6ey8 1
#
# COMPUTE FINISHED
# code, len 4efu 1
#
# COMPUTE FINISHED
# code, len 6ey9 1
#
# COMPUTE FINISHED
# code, len 6eyb 1
#
# COMPUTE FINISHED
# code, len 5oci 11
#
# COMPUTE FINISHED
# code, len 5odx 2
#
# COMPUTE FINISHED
# code, len 5nyh 3
#
# COMPUTE FINISHED
# code, len 5od7 7
#
# COMPUTE FINISHED
# code, len 6ei5 1
#
# COMPUTE FINISHED
# code, len 5lr1 2
#
# COMPUTE FINISHED
# code, len 6el5 1
#
# COMPUTE FINISHED
# code, len 5lo5 1
#
# COMPUTE FINISHED
# code, len 2ykj 1
#
# COMPUTE FINISHED
# code, len 5lny 24
#
# COMPUTE FINISHED
# code, len 4yay 2
#
# COMPUTE FINISHED
# code, len 6hlo 1
#
# COMPUTE FINISHED
# code, len 2nv6 1
#
# COMPUTE FINISHED
# code, len 2x22 1
#
# COMPUTE FINISHED
# code, len 2aqi 1
#
# COMPUTE FINISHED
# code, len 4iqk 1
#
# COMPUTE FINISHED
# code, len 5h0u 3
#
# COMPUTE FINISHED
# code, len 1hov 3
#
# COMPUTE FINISHED
# code, len 2ow1 3
#
# COMPUTE FINISHED
# code, len 5zhp 9
#
# COMPUTE FINISHED
# code, len 1kv1 2
#
# COMPUTE FINISHED
# code, len 1kv2 15
#
# COMPUTE FINISHED
# code, len 3zs5 1
#
# COMPUTE FINISHED
# code, len 3hll 1
#
# COMPUTE FINISHED
# code, len 5mtx 8
#
# COMPUTE FINISHED
# code, len 1oz1 1
#
# COMPUTE FINISHED
# code, len 5if1 3
#
# COMPUTE FINISHED
# code, len 1w98 3
#
# COMPUTE FINISHED
# code, len 3ddu 3
#
# COMPUTE FINISHED
# code, len 1bil 7
#
# COMPUTE FINISHED
# code, len 2v0z 1
#
# COMPUTE FINISHED
# code, len 6c4d 33
#
# COMPUTE FINISHED
# code, len 4ocz 1
#
# COMPUTE FINISHED
# code, len 4od0 19
#
# COMPUTE FINISHED
# code, len 5l8p 1
#
# COMPUTE FINISHED
# code, len 5l41 1
#
# COMPUTE FINISHED
# code, len 5l3u 1
#
# COMPUTE FINISHED
# code, len 2mgy 6
#
# COMPUTE FINISHED
# code, len 4wa4 1

# %%
#SS312A

import numpy as np
import pandas as pd
from collections import namedtuple
from math import log10
from copy import copy, deepcopy
from sklearn.neighbors import KDTree
from collections import Counter
import os
import sys
np.set_printoptions(threshold=sys.maxsize)
from Bio import SeqUtils


Mol = namedtuple('Mol', ['symbols', 'coords', 'message'])

#symbols is a list of atomic name to be met in the pdb
#kdtrees - is a dictionary of the KD-trees for each atom

PDB = namedtuple('PDB', ['symbols', 'kdtrees', 'coords'])

#res_types is a dictionary of residue information (name, chain, number) and its secondary structure info

Sec = namedtuple('Sec', ['res_types'])


def read_xyz(filename):
    f = open(filename, 'r')
    data = f.readlines()
    f.close()
    message = data[1].rstrip("\n")
    symbols = []
    coords = np.array([]).reshape((0, 3)).astype(float)
    for item in data[2:]:
        if item[0] != "H":
            item = item.strip("\n")
            item = item.split(" ")
            item = list(filter(None, item))
            symbols.append(item[0])
            coords = np.concatenate((coords, np.array(item[1:]).reshape((1,3)).astype(float)), 0)
    mol = Mol(symbols = symbols, coords = coords, message = message)
    mol.coords.astype(float)
    return mol


def read_pdb(filename):
    f = open(filename, 'r')
    data = f.readlines()
    f.close()
    #retain only lines containing atomic coordinates
    data = [line.rstrip("\n") for line in data if line.startswith("ATOM") or line.startswith("HETATM")]


    xyz = []
    symbols = []

    for lines in data:  
        if (lines[11:17].strip(' ')[0]) != ('H') and (lines[11:17].strip(' ')[0]) not in ('K'):
            if ((((lines[71:80])).strip(' ')[:2]).upper()) not in  ('LI', 'NA', 'RB', 'CS', 
                                                     'AU', 'BA', 'CA', 'CD', 'SR', 
                                                     'BE', 'CO', 'MG', 'CU', 'FE', 
                                                     'HG', 'MN', 'NI', 'ZN'):
                    symbols.append((lines[16:20].strip(' '), lines[21:22], lines[23:26].strip(' ')))
                    x = float(lines[30:37])
                    y = float(lines[38:45])
                    z = float(lines[46:53])
                    xyz.append([x, y, z])

    res_coord_pair = []

    for i in range(len(symbols)):
        res_coord_pair.append((symbols[i], xyz[i]))


    unique_resnames = (list(Counter(symbols).keys()))

    coords = {}

    for res in res_coord_pair:
        res_cur = res[0]
        coord_cur = res[1]
        if res_cur not in coords.keys():
            coords[res_cur] = []
        coords[res_cur].append(coord_cur)

    kdtrees = {}

    #create a dict of KD trees
    for res in coords.keys():
        #coords[res] = np.array(coords[res])
        kdtrees[res] = KDTree(coords[res], leaf_size=10)

    pdb = PDB(symbols=unique_resnames, kdtrees=kdtrees, coords=coords)
    return pdb

 
def read_dssp(filename):
    f = open(filename, 'r')
    readl = f.readlines()
    f.close()
    dssps = [line.rstrip("\n") for line in readl[28:]]    

    ssr = []
    for lines in dssps:
            ssr.append((lines[13:14], lines[11:13].strip(' '), lines[7:11].strip(' '), lines[16:17]))

    ss=[]
    for lines in ssr:
        if lines != ('!', '', '', ' '):
            
            ss.append(lines)

    residues=[]
    
    resnames=[]
    reschains=[]
    resnums=[]

    for n in range(len(ss)):
        resnames.append((str(SeqUtils.IUPACData.protein_letters_1to3.get(ss[n][0]))).upper())
        reschains.append(ss[n][1])
        resnums.append(ss[n][2])
        residues.append((resnames[n], reschains[n], resnums[n]))
    
    restypes=[]
    
    for n in range(len(ss)):
        for i in (ss[n][3]):
            if i == (' '):
                i = 'R'
            restypes.append(i)
            
    # restypes is a dict of residues vs types
    res_types = {}

    res_types = dict(zip(residues, restypes))

    sec = Sec(res_types = res_types)
    return sec     


def SS_desc(mol, pdb, sec):
    desc = [0.] * 3
    for atom_type in pdb.coords.keys():
        # check if the residue is in the structure
        # if not add zeros for the vector
            ind = pdb.kdtrees[atom_type].query_radius(mol.coords, r = 12)
            counts = ind
            for i in range(len(ind)):
                if len(counts[i]) != 0:
                    counts[i] = np.array(1)
                else:
                    counts[i] = np.array(0)
            #for i in range(mol.coords.shape[0]):

                #print(atom_type, mol.symbols[i], len(ind[i]))

                if sec.res_types.get(atom_type) == "H" or sec.res_types.get(atom_type) == "G" or sec.res_types.get(atom_type) == "I":
                    if mol.symbols[i] == "C":
                        desc[0] = desc[0] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[0] = desc[0] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[0] = desc[0] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[0] = desc[0] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[0] = desc[0] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[0] = desc[0] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[0] = desc[0] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[0] = desc[0] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[0] = desc[0] + counts[i]

                if sec.res_types.get(atom_type) == "B" or sec.res_types.get(atom_type) == "E":
                    if mol.symbols[i] == "C":
                        desc[1] = desc[1] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[1] = desc[1] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[1] = desc[1] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[1] = desc[1] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[1] = desc[1] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[1] = desc[1] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[1] = desc[1] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[1] = desc[1] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[1] = desc[1] + counts[i]

                if sec.res_types.get(atom_type) == "T" or sec.res_types.get(atom_type) == "S" or sec.res_types.get(atom_type) == "R":
                    if mol.symbols[i] == "C":
                        desc[2] = desc[2] + counts[i]
                    elif mol.symbols[i] == "O":
                        desc[2] = desc[2] + counts[i]
                    elif mol.symbols[i] == "N":
                        desc[2] = desc[2] + counts[i]
                    elif mol.symbols[i] == "S":
                        desc[2] = desc[2] + counts[i]
                    elif mol.symbols[i] == "P":
                        desc[2] = desc[2] + counts[i]
                    elif mol.symbols[i] == "F":
                        desc[2] = desc[2] + counts[i]
                    elif mol.symbols[i] == "Cl":
                        desc[2] = desc[2] + counts[i]
                    elif mol.symbols[i] == "Br":
                        desc[2] = desc[2] + counts[i]
                    elif mol.symbols[i] == "I":
                        desc[2] = desc[2] + counts[i]

    return desc

def compute(pdb_id):
    desc_arr = []
    mol_names_arr = []
    for i in range(1, 100):
        try:
            mol_names_arr.append(pdb_id + "_lig_{}".format(i))
            #print(pdb_id, "molnamesarr", mol_names_arr[-1])
            mol = read_xyz("./all/" + pdb_id + "/" + pdb_id + "_lig_{}.xyz".format(i))
            pdb = read_pdb("./all/" + pdb_id + "/" + pdb_id + "_prot_1.pdb")
            sec = read_dssp("./all/" + pdb_id + "/" + pdb_id + "_sec_1.dssp")

            desc = SS_desc(mol, pdb, sec)
            desc_arr.append(desc)

        except Exception as e:
            print("COMPUTE FINISHED", e)
            break
    return desc_arr, mol_names_arr


def main(): 
    data = pd.read_csv("./index_all.csv")
    codes = [code for code in list(Counter(data.docked_pdb).keys()) if len(code) == 4]
    X = []
    y = []
    try:
        for code in codes:
            desc_arr, mol_names_arr = compute(code)
            print("code, len", code, len(desc_arr), '\n')
            if desc_arr is not None:
                for desc_idx in range(len(desc_arr)):
                    desc_i = desc_arr[desc_idx]
                    mol_name_cur = mol_names_arr[desc_idx]
                    print("DF SIZE:", mol_name_cur, len(data[data.pose_filename == mol_name_cur]))
                    X.append(desc_i)
                    y.append(-log10(data[data.pose_filename == mol_name_cur].koff_s.iloc[0]))

                    #print(desc_i, data[data.pose_filename == mol_name_cur].koff_s.iloc[0])
            else:
                X.append(desc_i)
                y.append(-log10(data[data.pose_filename == mol_name_cur].koff_s.iloc[0]))

    except Exception as e:
        print("error in ", code, mol_name_cur,e)

    X = np.array(X).astype(int)
    y = np.array(y).astype(float)

    np.save("ss3_X_all.npy", X)
    np.save("ss3_y_all.npy", y)    

if __name__ == "__main__":
    main()
# Out:
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1xal/1xal_lig_4.xyz'
# code, len 1xal 3
#
# DF SIZE: 1xal_lig_1 1
# DF SIZE: 1xal_lig_2 1
# DF SIZE: 1xal_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2yme/2yme_lig_2.xyz'
# code, len 2yme 1
#
# DF SIZE: 2yme_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3uzc/3uzc_lig_11.xyz'
# code, len 3uzc 10
#
# DF SIZE: 3uzc_lig_1 1
# DF SIZE: 3uzc_lig_2 1
# DF SIZE: 3uzc_lig_3 1
# DF SIZE: 3uzc_lig_4 1
# DF SIZE: 3uzc_lig_5 1
# DF SIZE: 3uzc_lig_6 1
# DF SIZE: 3uzc_lig_7 1
# DF SIZE: 3uzc_lig_8 1
# DF SIZE: 3uzc_lig_9 1
# DF SIZE: 3uzc_lig_10 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ug2/4ug2_lig_2.xyz'
# code, len 4ug2 1
#
# DF SIZE: 4ug2_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2ydv/2ydv_lig_6.xyz'
# code, len 2ydv 5
#
# DF SIZE: 2ydv_lig_1 1
# DF SIZE: 2ydv_lig_2 1
# DF SIZE: 2ydv_lig_3 1
# DF SIZE: 2ydv_lig_4 1
# DF SIZE: 2ydv_lig_5 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3qak/3qak_lig_2.xyz'
# code, len 3qak 1
#
# DF SIZE: 3qak_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3iar/3iar_lig_2.xyz'
# code, len 3iar 1
#
# DF SIZE: 3iar_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5iz6/5iz6_lig_2.xyz'
# code, len 5iz6 1
#
# DF SIZE: 5iz6_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5z8h/5z8h_lig_2.xyz'
# code, len 5z8h 1
#
# DF SIZE: 5z8h_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1kvl/1kvl_lig_4.xyz'
# code, len 1kvl 3
#
# DF SIZE: 1kvl_lig_1 1
# DF SIZE: 1kvl_lig_2 1
# DF SIZE: 1kvl_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4wbg/4wbg_lig_2.xyz'
# code, len 4wbg 1
#
# DF SIZE: 4wbg_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2pu4/2pu4_lig_3.xyz'
# code, len 2pu4 2
#
# DF SIZE: 2pu4_lig_1 1
# DF SIZE: 2pu4_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ksq/4ksq_lig_2.xyz'
# code, len 4ksq 1
#
# DF SIZE: 4ksq_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ksp/4ksp_lig_2.xyz'
# code, len 4ksp 1
#
# DF SIZE: 4ksp_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6gpx/6gpx_lig_3.xyz'
# code, len 6gpx 2
#
# DF SIZE: 6gpx_lig_1 1
# DF SIZE: 6gpx_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek4/4ek4_lig_2.xyz'
# code, len 4ek4 1
#
# DF SIZE: 4ek4_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek6/4ek6_lig_2.xyz'
# code, len 4ek6 1
#
# DF SIZE: 4ek6_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkj/4fkj_lig_2.xyz'
# code, len 4fkj 1
#
# DF SIZE: 4fkj_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek8/4ek8_lig_6.xyz'
# code, len 4ek8 5
#
# DF SIZE: 4ek8_lig_1 1
# DF SIZE: 4ek8_lig_2 1
# DF SIZE: 4ek8_lig_3 1
# DF SIZE: 4ek8_lig_4 1
# DF SIZE: 4ek8_lig_5 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3sw4/3sw4_lig_2.xyz'
# code, len 3sw4 1
#
# DF SIZE: 3sw4_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3sw7/3sw7_lig_2.xyz'
# code, len 3sw7 1
#
# DF SIZE: 3sw7_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ek5/4ek5_lig_3.xyz'
# code, len 4ek5 2
#
# DF SIZE: 4ek5_lig_1 1
# DF SIZE: 4ek5_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fko/4fko_lig_2.xyz'
# code, len 4fko 1
#
# DF SIZE: 4fko_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkp/4fkp_lig_2.xyz'
# code, len 4fkp 1
#
# DF SIZE: 4fkp_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkq/4fkq_lig_2.xyz'
# code, len 4fkq 1
#
# DF SIZE: 4fkq_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkr/4fkr_lig_3.xyz'
# code, len 4fkr 2
#
# DF SIZE: 4fkr_lig_1 1
# DF SIZE: 4fkr_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fks/4fks_lig_2.xyz'
# code, len 4fks 1
#
# DF SIZE: 4fks_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkv/4fkv_lig_3.xyz'
# code, len 4fkv 2
#
# DF SIZE: 4fkv_lig_1 1
# DF SIZE: 4fkv_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkt/4fkt_lig_2.xyz'
# code, len 4fkt 1
#
# DF SIZE: 4fkt_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fku/4fku_lig_2.xyz'
# code, len 4fku 1
#
# DF SIZE: 4fku_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkw/4fkw_lig_2.xyz'
# code, len 4fkw 1
#
# DF SIZE: 4fkw_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fkg/4fkg_lig_2.xyz'
# code, len 4fkg 1
#
# DF SIZE: 4fkg_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4fki/4fki_lig_2.xyz'
# code, len 4fki 1
#
# DF SIZE: 4fki_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f7n/4f7n_lig_3.xyz'
# code, len 4f7n 2
#
# DF SIZE: 4f7n_lig_1 1
# DF SIZE: 4f7n_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f6u/4f6u_lig_2.xyz'
# code, len 4f6u 1
#
# DF SIZE: 4f6u_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f6w/4f6w_lig_2.xyz'
# code, len 4f6w 1
#
# DF SIZE: 4f6w_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4f7l/4f7l_lig_2.xyz'
# code, len 4f7l 1
#
# DF SIZE: 4f7l_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5eqy/5eqy_lig_8.xyz'
# code, len 5eqy 7
#
# DF SIZE: 5eqy_lig_1 1
# DF SIZE: 5eqy_lig_2 1
# DF SIZE: 5eqy_lig_3 1
# DF SIZE: 5eqy_lig_4 1
# DF SIZE: 5eqy_lig_5 1
# DF SIZE: 5eqy_lig_6 1
# DF SIZE: 5eqy_lig_7 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1nfx/1nfx_lig_5.xyz'
# code, len 1nfx 4
#
# DF SIZE: 1nfx_lig_1 1
# DF SIZE: 1nfx_lig_2 1
# DF SIZE: 1nfx_lig_3 1
# DF SIZE: 1nfx_lig_4 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4z9g/4z9g_lig_27.xyz'
# code, len 4z9g 26
#
# DF SIZE: 4z9g_lig_1 1
# DF SIZE: 4z9g_lig_2 1
# DF SIZE: 4z9g_lig_3 1
# DF SIZE: 4z9g_lig_4 1
# DF SIZE: 4z9g_lig_5 1
# DF SIZE: 4z9g_lig_6 1
# DF SIZE: 4z9g_lig_7 1
# DF SIZE: 4z9g_lig_8 1
# DF SIZE: 4z9g_lig_9 1
# DF SIZE: 4z9g_lig_10 1
# DF SIZE: 4z9g_lig_11 1
# DF SIZE: 4z9g_lig_12 1
# DF SIZE: 4z9g_lig_13 1
# DF SIZE: 4z9g_lig_14 1
# DF SIZE: 4z9g_lig_15 1
# DF SIZE: 4z9g_lig_16 1
# DF SIZE: 4z9g_lig_17 1
# DF SIZE: 4z9g_lig_18 1
# DF SIZE: 4z9g_lig_19 1
# DF SIZE: 4z9g_lig_20 1
# DF SIZE: 4z9g_lig_21 1
# DF SIZE: 4z9g_lig_22 1
# DF SIZE: 4z9g_lig_23 1
# DF SIZE: 4z9g_lig_24 1
# DF SIZE: 4z9g_lig_25 1
# DF SIZE: 4z9g_lig_26 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1u73/1u73_lig_3.xyz'
# code, len 1u73 2
#
# DF SIZE: 1u73_lig_1 1
# DF SIZE: 1u73_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1u72/1u72_lig_3.xyz'
# code, len 1u72 2
#
# DF SIZE: 1u72_lig_1 1
# DF SIZE: 1u72_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1u74/1u74_lig_2.xyz'
# code, len 1u74 1
#
# DF SIZE: 1u74_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ekg/4ekg_lig_3.xyz'
# code, len 4ekg 2
#
# DF SIZE: 4ekg_lig_1 1
# DF SIZE: 4ekg_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4eki/4eki_lig_2.xyz'
# code, len 4eki 1
#
# DF SIZE: 4eki_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3qox/3qox_lig_2.xyz'
# code, len 3qox 1
#
# DF SIZE: 3qox_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3g0b/3g0b_lig_3.xyz'
# code, len 3g0b 2
#
# DF SIZE: 3g0b_lig_1 1
# DF SIZE: 3g0b_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2rgu/2rgu_lig_3.xyz'
# code, len 2rgu 2
#
# DF SIZE: 2rgu_lig_1 1
# DF SIZE: 2rgu_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3bjm/3bjm_lig_2.xyz'
# code, len 3bjm 1
#
# DF SIZE: 3bjm_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1x70/1x70_lig_2.xyz'
# code, len 1x70 1
#
# DF SIZE: 1x70_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3vjk/3vjk_lig_2.xyz'
# code, len 3vjk 1
#
# DF SIZE: 3vjk_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3w2t/3w2t_lig_2.xyz'
# code, len 3w2t 1
#
# DF SIZE: 3w2t_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1xkk/1xkk_lig_2.xyz'
# code, len 1xkk 1
#
# DF SIZE: 1xkk_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1qg6/1qg6_lig_2.xyz'
# code, len 1qg6 1
#
# DF SIZE: 1qg6_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4p5z/4p5z_lig_3.xyz'
# code, len 4p5z 2
#
# DF SIZE: 4p5z_lig_1 1
# DF SIZE: 4p5z_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2aay/2aay_lig_3.xyz'
# code, len 2aay 2
#
# DF SIZE: 2aay_lig_1 1
# DF SIZE: 2aay_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3nrc/3nrc_lig_6.xyz'
# code, len 3nrc 5
#
# DF SIZE: 3nrc_lig_1 1
# DF SIZE: 3nrc_lig_2 1
# DF SIZE: 3nrc_lig_3 1
# DF SIZE: 3nrc_lig_4 1
# DF SIZE: 3nrc_lig_5 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4no7/4no7_lig_3.xyz'
# code, len 4no7 2
#
# DF SIZE: 4no7_lig_1 1
# DF SIZE: 4no7_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3f9m/3f9m_lig_3.xyz'
# code, len 3f9m 2
#
# DF SIZE: 3f9m_lig_1 1
# DF SIZE: 3f9m_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1jyq/1jyq_lig_3.xyz'
# code, len 1jyq 2
#
# DF SIZE: 1jyq_lig_1 1
# DF SIZE: 1jyq_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ldo/3ldo_lig_2.xyz'
# code, len 3ldo 1
#
# DF SIZE: 3ldo_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ldp/3ldp_lig_8.xyz'
# code, len 3ldp 7
#
# DF SIZE: 3ldp_lig_1 1
# DF SIZE: 3ldp_lig_2 1
# DF SIZE: 3ldp_lig_3 1
# DF SIZE: 3ldp_lig_4 1
# DF SIZE: 3ldp_lig_5 1
# DF SIZE: 3ldp_lig_6 1
# DF SIZE: 3ldp_lig_7 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5uen/5uen_lig_12.xyz'
# code, len 5uen 11
#
# DF SIZE: 5uen_lig_1 1
# DF SIZE: 5uen_lig_2 1
# DF SIZE: 5uen_lig_3 1
# DF SIZE: 5uen_lig_4 1
# DF SIZE: 5uen_lig_5 1
# DF SIZE: 5uen_lig_6 1
# DF SIZE: 5uen_lig_7 1
# DF SIZE: 5uen_lig_8 1
# DF SIZE: 5uen_lig_9 1
# DF SIZE: 5uen_lig_10 1
# DF SIZE: 5uen_lig_11 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6fag/6fag_lig_3.xyz'
# code, len 6fag 2
#
# DF SIZE: 6fag_lig_1 1
# DF SIZE: 6fag_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6f3b/6f3b_lig_2.xyz'
# code, len 6f3b 1
#
# DF SIZE: 6f3b_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1czm/1czm_lig_4.xyz'
# code, len 1czm 3
#
# DF SIZE: 1czm_lig_1 1
# DF SIZE: 1czm_lig_2 1
# DF SIZE: 1czm_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5gmm/5gmm_lig_2.xyz'
# code, len 5gmm 1
#
# DF SIZE: 5gmm_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4wr7/4wr7_lig_3.xyz'
# code, len 4wr7 2
#
# DF SIZE: 4wr7_lig_1 1
# DF SIZE: 4wr7_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4qsi/4qsi_lig_4.xyz'
# code, len 4qsi 3
#
# DF SIZE: 4qsi_lig_1 1
# DF SIZE: 4qsi_lig_2 1
# DF SIZE: 4qsi_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3m98/3m98_lig_3.xyz'
# code, len 3m98 2
#
# DF SIZE: 3m98_lig_1 1
# DF SIZE: 3m98_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4knj/4knj_lig_4.xyz'
# code, len 4knj 3
#
# DF SIZE: 4knj_lig_1 1
# DF SIZE: 4knj_lig_2 1
# DF SIZE: 4knj_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3sbi/3sbi_lig_3.xyz'
# code, len 3sbi 2
#
# DF SIZE: 3sbi_lig_1 1
# DF SIZE: 3sbi_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3s9t/3s9t_lig_2.xyz'
# code, len 3s9t 1
#
# DF SIZE: 3s9t_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5ll4/5ll4_lig_2.xyz'
# code, len 5ll4 1
#
# DF SIZE: 5ll4_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5fl5/5fl5_lig_8.xyz'
# code, len 5fl5 7
#
# DF SIZE: 5fl5_lig_1 1
# DF SIZE: 5fl5_lig_2 1
# DF SIZE: 5fl5_lig_3 1
# DF SIZE: 5fl5_lig_4 1
# DF SIZE: 5fl5_lig_5 1
# DF SIZE: 5fl5_lig_6 1
# DF SIZE: 5fl5_lig_7 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6fe0/6fe0_lig_9.xyz'
# code, len 6fe0 8
#
# DF SIZE: 6fe0_lig_1 1
# DF SIZE: 6fe0_lig_2 1
# DF SIZE: 6fe0_lig_3 1
# DF SIZE: 6fe0_lig_4 1
# DF SIZE: 6fe0_lig_5 1
# DF SIZE: 6fe0_lig_6 1
# DF SIZE: 6fe0_lig_7 1
# DF SIZE: 6fe0_lig_8 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6h37/6h37_lig_14.xyz'
# code, len 6h37 13
#
# DF SIZE: 6h37_lig_1 1
# DF SIZE: 6h37_lig_2 1
# DF SIZE: 6h37_lig_3 1
# DF SIZE: 6h37_lig_4 1
# DF SIZE: 6h37_lig_5 1
# DF SIZE: 6h37_lig_6 1
# DF SIZE: 6h37_lig_7 1
# DF SIZE: 6h37_lig_8 1
# DF SIZE: 6h37_lig_9 1
# DF SIZE: 6h37_lig_10 1
# DF SIZE: 6h37_lig_11 1
# DF SIZE: 6h37_lig_12 1
# DF SIZE: 6h37_lig_13 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5ll5/5ll5_lig_3.xyz'
# code, len 5ll5 2
#
# DF SIZE: 5ll5_lig_1 1
# DF SIZE: 5ll5_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5ll9/5ll9_lig_4.xyz'
# code, len 5ll9 3
#
# DF SIZE: 5ll9_lig_1 1
# DF SIZE: 5ll9_lig_2 1
# DF SIZE: 5ll9_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4kp5/4kp5_lig_3.xyz'
# code, len 4kp5 2
#
# DF SIZE: 4kp5_lig_1 1
# DF SIZE: 4kp5_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6g7a/6g7a_lig_3.xyz'
# code, len 6g7a 2
#
# DF SIZE: 6g7a_lig_1 1
# DF SIZE: 6g7a_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4qjo/4qjo_lig_5.xyz'
# code, len 4qjo 4
#
# DF SIZE: 4qjo_lig_1 1
# DF SIZE: 4qjo_lig_2 1
# DF SIZE: 4qjo_lig_3 1
# DF SIZE: 4qjo_lig_4 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4qjw/4qjw_lig_2.xyz'
# code, len 4qjw 1
#
# DF SIZE: 4qjw_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3p8o/3p8o_lig_2.xyz'
# code, len 3p8o 1
#
# DF SIZE: 3p8o_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3p8n/3p8n_lig_2.xyz'
# code, len 3p8n 1
#
# DF SIZE: 3p8n_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4dru/4dru_lig_9.xyz'
# code, len 4dru 8
#
# DF SIZE: 4dru_lig_1 1
# DF SIZE: 4dru_lig_2 1
# DF SIZE: 4dru_lig_3 1
# DF SIZE: 4dru_lig_4 1
# DF SIZE: 4dru_lig_5 1
# DF SIZE: 4dru_lig_6 1
# DF SIZE: 4dru_lig_7 1
# DF SIZE: 4dru_lig_8 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3rze/3rze_lig_2.xyz'
# code, len 3rze 1
#
# DF SIZE: 3rze_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1qbs/1qbs_lig_3.xyz'
# code, len 1qbs 2
#
# DF SIZE: 1qbs_lig_1 1
# DF SIZE: 1qbs_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ebw/1ebw_lig_13.xyz'
# code, len 1ebw 12
#
# DF SIZE: 1ebw_lig_1 1
# DF SIZE: 1ebw_lig_2 1
# DF SIZE: 1ebw_lig_3 1
# DF SIZE: 1ebw_lig_4 1
# DF SIZE: 1ebw_lig_5 1
# DF SIZE: 1ebw_lig_6 1
# DF SIZE: 1ebw_lig_7 1
# DF SIZE: 1ebw_lig_8 1
# DF SIZE: 1ebw_lig_9 1
# DF SIZE: 1ebw_lig_10 1
# DF SIZE: 1ebw_lig_11 1
# DF SIZE: 1ebw_lig_12 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ajv/1ajv_lig_5.xyz'
# code, len 1ajv 4
#
# DF SIZE: 1ajv_lig_1 1
# DF SIZE: 1ajv_lig_2 1
# DF SIZE: 1ajv_lig_3 1
# DF SIZE: 1ajv_lig_4 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4njv/4njv_lig_3.xyz'
# code, len 4njv 2
#
# DF SIZE: 4njv_lig_1 1
# DF SIZE: 4njv_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ec2/1ec2_lig_7.xyz'
# code, len 1ec2 6
#
# DF SIZE: 1ec2_lig_1 1
# DF SIZE: 1ec2_lig_2 1
# DF SIZE: 1ec2_lig_3 1
# DF SIZE: 1ec2_lig_4 1
# DF SIZE: 1ec2_lig_5 1
# DF SIZE: 1ec2_lig_6 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ekv/3ekv_lig_2.xyz'
# code, len 3ekv 1
#
# DF SIZE: 3ekv_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1d4h/1d4h_lig_6.xyz'
# code, len 1d4h 5
#
# DF SIZE: 1d4h_lig_1 1
# DF SIZE: 1d4h_lig_2 1
# DF SIZE: 1d4h_lig_3 1
# DF SIZE: 1d4h_lig_4 1
# DF SIZE: 1d4h_lig_5 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1eby/1eby_lig_2.xyz'
# code, len 1eby 1
#
# DF SIZE: 1eby_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ebz/1ebz_lig_2.xyz'
# code, len 1ebz 1
#
# DF SIZE: 1ebz_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ec1/1ec1_lig_2.xyz'
# code, len 1ec1 1
#
# DF SIZE: 1ec1_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1d4i/1d4i_lig_2.xyz'
# code, len 1d4i 1
#
# DF SIZE: 1d4i_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ekx/3ekx_lig_2.xyz'
# code, len 3ekx 1
#
# DF SIZE: 3ekx_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1hxw/1hxw_lig_2.xyz'
# code, len 1hxw 1
#
# DF SIZE: 1hxw_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1hiv/1hiv_lig_2.xyz'
# code, len 1hiv 1
#
# DF SIZE: 1hiv_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1ikw/1ikw_lig_2.xyz'
# code, len 1ikw 1
#
# DF SIZE: 1ikw_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2uwd/2uwd_lig_2.xyz'
# code, len 2uwd 1
#
# DF SIZE: 2uwd_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2bsm/2bsm_lig_5.xyz'
# code, len 2bsm 4
#
# DF SIZE: 2bsm_lig_1 1
# DF SIZE: 2bsm_lig_2 1
# DF SIZE: 2bsm_lig_3 1
# DF SIZE: 2bsm_lig_4 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j2x/5j2x_lig_2.xyz'
# code, len 5j2x 1
#
# DF SIZE: 5j2x_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6f1n/6f1n_lig_2.xyz'
# code, len 6f1n 1
#
# DF SIZE: 6f1n_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6elo/6elo_lig_3.xyz'
# code, len 6elo 2
#
# DF SIZE: 6elo_lig_1 1
# DF SIZE: 6elo_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j64/5j64_lig_5.xyz'
# code, len 5j64 4
#
# DF SIZE: 5j64_lig_1 1
# DF SIZE: 5j64_lig_2 1
# DF SIZE: 5j64_lig_3 1
# DF SIZE: 5j64_lig_4 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6eln/6eln_lig_2.xyz'
# code, len 6eln 1
#
# DF SIZE: 6eln_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j20/5j20_lig_3.xyz'
# code, len 5j20 2
#
# DF SIZE: 5j20_lig_1 1
# DF SIZE: 5j20_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j86/5j86_lig_9.xyz'
# code, len 5j86 8
#
# DF SIZE: 5j86_lig_1 1
# DF SIZE: 5j86_lig_2 1
# DF SIZE: 5j86_lig_3 1
# DF SIZE: 5j86_lig_4 1
# DF SIZE: 5j86_lig_5 1
# DF SIZE: 5j86_lig_6 1
# DF SIZE: 5j86_lig_7 1
# DF SIZE: 5j86_lig_8 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j9x/5j9x_lig_5.xyz'
# code, len 5j9x 4
#
# DF SIZE: 5j9x_lig_1 1
# DF SIZE: 5j9x_lig_2 1
# DF SIZE: 5j9x_lig_3 1
# DF SIZE: 5j9x_lig_4 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6elp/6elp_lig_4.xyz'
# code, len 6elp 3
#
# DF SIZE: 6elp_lig_1 1
# DF SIZE: 6elp_lig_2 1
# DF SIZE: 6elp_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j27/5j27_lig_2.xyz'
# code, len 5j27 1
#
# DF SIZE: 5j27_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5j82/5j82_lig_3.xyz'
# code, len 5j82 2
#
# DF SIZE: 5j82_lig_1 1
# DF SIZE: 5j82_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lrz/5lrz_lig_2.xyz'
# code, len 5lrz 1
#
# DF SIZE: 5lrz_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lr7/5lr7_lig_2.xyz'
# code, len 5lr7 1
#
# DF SIZE: 5lr7_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2yki/2yki_lig_2.xyz'
# code, len 2yki 1
#
# DF SIZE: 2yki_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lq9/5lq9_lig_2.xyz'
# code, len 5lq9 1
#
# DF SIZE: 5lq9_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5ls1/5ls1_lig_2.xyz'
# code, len 5ls1 1
#
# DF SIZE: 5ls1_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5t21/5t21_lig_2.xyz'
# code, len 5t21 1
#
# DF SIZE: 5t21_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6eya/6eya_lig_2.xyz'
# code, len 6eya 1
#
# DF SIZE: 6eya_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lo6/5lo6_lig_2.xyz'
# code, len 5lo6 1
#
# DF SIZE: 5lo6_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lnz/5lnz_lig_2.xyz'
# code, len 5lnz 1
#
# DF SIZE: 5lnz_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6ey8/6ey8_lig_2.xyz'
# code, len 6ey8 1
#
# DF SIZE: 6ey8_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4efu/4efu_lig_2.xyz'
# code, len 4efu 1
#
# DF SIZE: 4efu_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6ey9/6ey9_lig_2.xyz'
# code, len 6ey9 1
#
# DF SIZE: 6ey9_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6eyb/6eyb_lig_2.xyz'
# code, len 6eyb 1
#
# DF SIZE: 6eyb_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5oci/5oci_lig_12.xyz'
# code, len 5oci 11
#
# DF SIZE: 5oci_lig_1 1
# DF SIZE: 5oci_lig_2 1
# DF SIZE: 5oci_lig_3 1
# DF SIZE: 5oci_lig_4 1
# DF SIZE: 5oci_lig_5 1
# DF SIZE: 5oci_lig_6 1
# DF SIZE: 5oci_lig_7 1
# DF SIZE: 5oci_lig_8 1
# DF SIZE: 5oci_lig_9 1
# DF SIZE: 5oci_lig_10 1
# DF SIZE: 5oci_lig_11 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5odx/5odx_lig_3.xyz'
# code, len 5odx 2
#
# DF SIZE: 5odx_lig_1 1
# DF SIZE: 5odx_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5nyh/5nyh_lig_4.xyz'
# code, len 5nyh 3
#
# DF SIZE: 5nyh_lig_1 1
# DF SIZE: 5nyh_lig_2 1
# DF SIZE: 5nyh_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5od7/5od7_lig_8.xyz'
# code, len 5od7 7
#
# DF SIZE: 5od7_lig_1 1
# DF SIZE: 5od7_lig_2 1
# DF SIZE: 5od7_lig_3 1
# DF SIZE: 5od7_lig_4 1
# DF SIZE: 5od7_lig_5 1
# DF SIZE: 5od7_lig_6 1
# DF SIZE: 5od7_lig_7 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6ei5/6ei5_lig_2.xyz'
# code, len 6ei5 1
#
# DF SIZE: 6ei5_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lr1/5lr1_lig_3.xyz'
# code, len 5lr1 2
#
# DF SIZE: 5lr1_lig_1 1
# DF SIZE: 5lr1_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6el5/6el5_lig_2.xyz'
# code, len 6el5 1
#
# DF SIZE: 6el5_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lo5/5lo5_lig_2.xyz'
# code, len 5lo5 1
#
# DF SIZE: 5lo5_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2ykj/2ykj_lig_2.xyz'
# code, len 2ykj 1
#
# DF SIZE: 2ykj_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5lny/5lny_lig_25.xyz'
# code, len 5lny 24
#
# DF SIZE: 5lny_lig_1 1
# DF SIZE: 5lny_lig_2 1
# DF SIZE: 5lny_lig_3 1
# DF SIZE: 5lny_lig_4 1
# DF SIZE: 5lny_lig_5 1
# DF SIZE: 5lny_lig_6 1
# DF SIZE: 5lny_lig_7 1
# DF SIZE: 5lny_lig_8 1
# DF SIZE: 5lny_lig_9 1
# DF SIZE: 5lny_lig_10 1
# DF SIZE: 5lny_lig_11 1
# DF SIZE: 5lny_lig_12 1
# DF SIZE: 5lny_lig_13 1
# DF SIZE: 5lny_lig_14 1
# DF SIZE: 5lny_lig_15 1
# DF SIZE: 5lny_lig_16 1
# DF SIZE: 5lny_lig_17 1
# DF SIZE: 5lny_lig_18 1
# DF SIZE: 5lny_lig_19 1
# DF SIZE: 5lny_lig_20 1
# DF SIZE: 5lny_lig_21 1
# DF SIZE: 5lny_lig_22 1
# DF SIZE: 5lny_lig_23 1
# DF SIZE: 5lny_lig_24 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4yay/4yay_lig_3.xyz'
# code, len 4yay 2
#
# DF SIZE: 4yay_lig_1 1
# DF SIZE: 4yay_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6hlo/6hlo_lig_2.xyz'
# code, len 6hlo 1
#
# DF SIZE: 6hlo_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2nv6/2nv6_lig_2.xyz'
# code, len 2nv6 1
#
# DF SIZE: 2nv6_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2x22/2x22_lig_2.xyz'
# code, len 2x22 1
#
# DF SIZE: 2x22_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2aqi/2aqi_lig_2.xyz'
# code, len 2aqi 1
#
# DF SIZE: 2aqi_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4iqk/4iqk_lig_2.xyz'
# code, len 4iqk 1
#
# DF SIZE: 4iqk_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5h0u/5h0u_lig_4.xyz'
# code, len 5h0u 3
#
# DF SIZE: 5h0u_lig_1 1
# DF SIZE: 5h0u_lig_2 1
# DF SIZE: 5h0u_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1hov/1hov_lig_4.xyz'
# code, len 1hov 3
#
# DF SIZE: 1hov_lig_1 1
# DF SIZE: 1hov_lig_2 1
# DF SIZE: 1hov_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2ow1/2ow1_lig_4.xyz'
# code, len 2ow1 3
#
# DF SIZE: 2ow1_lig_1 1
# DF SIZE: 2ow1_lig_2 1
# DF SIZE: 2ow1_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5zhp/5zhp_lig_10.xyz'
# code, len 5zhp 9
#
# DF SIZE: 5zhp_lig_1 1
# DF SIZE: 5zhp_lig_2 1
# DF SIZE: 5zhp_lig_3 1
# DF SIZE: 5zhp_lig_4 1
# DF SIZE: 5zhp_lig_5 1
# DF SIZE: 5zhp_lig_6 1
# DF SIZE: 5zhp_lig_7 1
# DF SIZE: 5zhp_lig_8 1
# DF SIZE: 5zhp_lig_9 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1kv1/1kv1_lig_3.xyz'
# code, len 1kv1 2
#
# DF SIZE: 1kv1_lig_1 1
# DF SIZE: 1kv1_lig_2 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1kv2/1kv2_lig_16.xyz'
# code, len 1kv2 15
#
# DF SIZE: 1kv2_lig_1 1
# DF SIZE: 1kv2_lig_2 1
# DF SIZE: 1kv2_lig_3 1
# DF SIZE: 1kv2_lig_4 1
# DF SIZE: 1kv2_lig_5 1
# DF SIZE: 1kv2_lig_6 1
# DF SIZE: 1kv2_lig_7 1
# DF SIZE: 1kv2_lig_8 1
# DF SIZE: 1kv2_lig_9 1
# DF SIZE: 1kv2_lig_10 1
# DF SIZE: 1kv2_lig_11 1
# DF SIZE: 1kv2_lig_12 1
# DF SIZE: 1kv2_lig_13 1
# DF SIZE: 1kv2_lig_14 1
# DF SIZE: 1kv2_lig_15 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3zs5/3zs5_lig_2.xyz'
# code, len 3zs5 1
#
# DF SIZE: 3zs5_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3hll/3hll_lig_2.xyz'
# code, len 3hll 1
#
# DF SIZE: 3hll_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5mtx/5mtx_lig_9.xyz'
# code, len 5mtx 8
#
# DF SIZE: 5mtx_lig_1 1
# DF SIZE: 5mtx_lig_2 1
# DF SIZE: 5mtx_lig_3 1
# DF SIZE: 5mtx_lig_4 1
# DF SIZE: 5mtx_lig_5 1
# DF SIZE: 5mtx_lig_6 1
# DF SIZE: 5mtx_lig_7 1
# DF SIZE: 5mtx_lig_8 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1oz1/1oz1_lig_2.xyz'
# code, len 1oz1 1
#
# DF SIZE: 1oz1_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5if1/5if1_lig_4.xyz'
# code, len 5if1 3
#
# DF SIZE: 5if1_lig_1 1
# DF SIZE: 5if1_lig_2 1
# DF SIZE: 5if1_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1w98/1w98_lig_4.xyz'
# code, len 1w98 3
#
# DF SIZE: 1w98_lig_1 1
# DF SIZE: 1w98_lig_2 1
# DF SIZE: 1w98_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/3ddu/3ddu_lig_4.xyz'
# code, len 3ddu 3
#
# DF SIZE: 3ddu_lig_1 1
# DF SIZE: 3ddu_lig_2 1
# DF SIZE: 3ddu_lig_3 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/1bil/1bil_lig_8.xyz'
# code, len 1bil 7
#
# DF SIZE: 1bil_lig_1 1
# DF SIZE: 1bil_lig_2 1
# DF SIZE: 1bil_lig_3 1
# DF SIZE: 1bil_lig_4 1
# DF SIZE: 1bil_lig_5 1
# DF SIZE: 1bil_lig_6 1
# DF SIZE: 1bil_lig_7 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2v0z/2v0z_lig_2.xyz'
# code, len 2v0z 1
#
# DF SIZE: 2v0z_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/6c4d/6c4d_lig_34.xyz'
# code, len 6c4d 33
#
# DF SIZE: 6c4d_lig_1 1
# DF SIZE: 6c4d_lig_2 1
# DF SIZE: 6c4d_lig_3 1
# DF SIZE: 6c4d_lig_4 1
# DF SIZE: 6c4d_lig_5 1
# DF SIZE: 6c4d_lig_6 1
# DF SIZE: 6c4d_lig_7 1
# DF SIZE: 6c4d_lig_8 1
# DF SIZE: 6c4d_lig_9 1
# DF SIZE: 6c4d_lig_10 1
# DF SIZE: 6c4d_lig_11 1
# DF SIZE: 6c4d_lig_12 1
# DF SIZE: 6c4d_lig_13 1
# DF SIZE: 6c4d_lig_14 1
# DF SIZE: 6c4d_lig_15 1
# DF SIZE: 6c4d_lig_16 1
# DF SIZE: 6c4d_lig_17 1
# DF SIZE: 6c4d_lig_18 1
# DF SIZE: 6c4d_lig_19 1
# DF SIZE: 6c4d_lig_20 1
# DF SIZE: 6c4d_lig_21 1
# DF SIZE: 6c4d_lig_22 1
# DF SIZE: 6c4d_lig_23 1
# DF SIZE: 6c4d_lig_24 1
# DF SIZE: 6c4d_lig_25 1
# DF SIZE: 6c4d_lig_26 1
# DF SIZE: 6c4d_lig_27 1
# DF SIZE: 6c4d_lig_28 1
# DF SIZE: 6c4d_lig_29 1
# DF SIZE: 6c4d_lig_30 1
# DF SIZE: 6c4d_lig_31 1
# DF SIZE: 6c4d_lig_32 1
# DF SIZE: 6c4d_lig_33 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4ocz/4ocz_lig_2.xyz'
# code, len 4ocz 1
#
# DF SIZE: 4ocz_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4od0/4od0_lig_20.xyz'
# code, len 4od0 19
#
# DF SIZE: 4od0_lig_1 1
# DF SIZE: 4od0_lig_2 1
# DF SIZE: 4od0_lig_3 1
# DF SIZE: 4od0_lig_4 1
# DF SIZE: 4od0_lig_5 1
# DF SIZE: 4od0_lig_6 1
# DF SIZE: 4od0_lig_7 1
# DF SIZE: 4od0_lig_8 1
# DF SIZE: 4od0_lig_9 1
# DF SIZE: 4od0_lig_10 1
# DF SIZE: 4od0_lig_11 1
# DF SIZE: 4od0_lig_12 1
# DF SIZE: 4od0_lig_13 1
# DF SIZE: 4od0_lig_14 1
# DF SIZE: 4od0_lig_15 1
# DF SIZE: 4od0_lig_16 1
# DF SIZE: 4od0_lig_17 1
# DF SIZE: 4od0_lig_18 1
# DF SIZE: 4od0_lig_19 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5l8p/5l8p_lig_2.xyz'
# code, len 5l8p 1
#
# DF SIZE: 5l8p_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5l41/5l41_lig_2.xyz'
# code, len 5l41 1
#
# DF SIZE: 5l41_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/5l3u/5l3u_lig_2.xyz'
# code, len 5l3u 1
#
# DF SIZE: 5l3u_lig_1 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/2mgy/2mgy_lig_7.xyz'
# code, len 2mgy 6
#
# DF SIZE: 2mgy_lig_1 1
# DF SIZE: 2mgy_lig_2 1
# DF SIZE: 2mgy_lig_3 1
# DF SIZE: 2mgy_lig_4 1
# DF SIZE: 2mgy_lig_5 1
# DF SIZE: 2mgy_lig_6 1
# COMPUTE FINISHED [Errno 2] No such file or directory: './all/4wa4/4wa4_lig_2.xyz'
# code, len 4wa4 1
#
# DF SIZE: 4wa4_lig_1 1
